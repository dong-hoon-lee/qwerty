# %% [markdown]
# <h1 align="center">KRX Big-Data</h1>
#
# # [ 1 ] Overview
#
# ### 1. Sources
#
#  - `[유가증권]일별 시세정보(주문번호-1300-27)` : 2020년 1분기 주식 정보 -> _CSV 형식_
#  - `[유가증권]일별 시세정보(주문번호-1300-30)` : 2021년 1분기 주식 정보 -> _CSV 형식_
#  - `[유가증권]일별 시세정보(주문번호-1300-33)` : 2022년 1분기 주식 정보 -> _CSV 형식_
#
# <br><br><br>
#
# ### 2. Targets from `.CSV` files (Input)
#
# | 항목 명 | 항목 영어명 |
# |:---:|:---:|
# |`거래일자`|TRD_DD|
# |`종목코드`|ISU_CD|
# |`종목명`|ISU_NM|
# |`시가`|OPNPRC|
# |`고가`|HGPRC|
# |`저가`|LWPRC|
# |`종가`|CLSPRC|
# |(누적)`거래량`|ACC_TRDVOL|
# |`업종구분`(지수업종코드)|IDX_IND_CD|
# |`PER`(주가수익률)|PER|
# |`상장일`|LIST_DD|
# |`시가총액`|MKTCAP|
#
# <br><br><br>
#
# ### 3. Results (Output)
#
# | Property | Description |
# |:---:|:---:|
# |TRD_DD|`거래일자`|
# |ISU_CD|`종목코드`|
# |ISU_NM|`종목명`|
# |OPNPRC|`시가`|
# |HGPRC|`고가`|
# |LWPRC|`저가`|
# |CLSPRC|`종가`|
# |ACC_TRDVOL|(누적)`거래량`|
# |IDX_IND_CD|`업종구분`(지수업종코드)|
# |PER|`PER`(주가수익률)|
# |LIST_DD|`상장일`|
# |MKTCAP|`시가총액`|
#
# <br><br><br><hr>

# %% [markdown]
# # [ 2 ] Importing Modules

# %%
# Data Handlers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Code Libraries
import os
import copy
import abc

# %% [markdown]
# <br><br><br>

# %% [markdown]
# # [ 3 ] Declarations

# %%
import copy

############################################################################################################

class Utils:
    """
    데이터 처리를 위해 유용한 기능들을 정의한 클래스입니다.
    """
    @staticmethod
    def generate_int_range(start:int, end:int)->iter:
        """
        start와 end 사이의 정수들을 반환하는 Generator입니다.
        """
        if(start >= end):
            raise SyntaxError(f"{start} must be larger than {end}")
        while start <= end:
            yield start
            start += 1
            
    """
    깊은 복사를 한 인스턴스를 반환합니다.
    """
    @staticmethod
    def clone(target:object)->object:
        return copy.deepcopy(target)
    
            
############################################################################################################

import pandas

class PandasBasedCSVHandler:
    """
    Pandas 모듈을 기반으로 CSV 파일 데이터를 다루는 클래스입니다.
    """
    def __init__(self, handler:pandas)->None:
        self.__handler = handler
        self.__data = dict()
        
    @property
    def handler(self)->pandas:
        """
        주입받은 Pandas 객체를 반환합니다.
        이미 생성된 handler 인스턴스는 대체될 수 없고 반환만 가능합니다.
        """
        return self.__handler
    
    def take_data_from_CSV_file(self, *, data_id:object, filepath:str, encoding:str="utf-8")->object:
        """
        불러올 CSV 파일의 경로를 받아 데이터를 가져오고
        데이터를 식별할 data_id를 받습니다.
        Argument를 반드시 키워드로 명시하여 Parameter에 전달해야 합니다.
        """
        self.__data[data_id] = self.__handler.read_csv(filepath, encoding=encoding)
        return self
    
    def get_CSV_data(self)->dict:
        """
        다음 Dictionary 자료구조를 반환합니다.
        key의 타입(자료형)은 정수형으로 의도되었지만 어떤 타입이 들어올지는 자유입니다.
        value는 Pandas 타입의 객체입니다.
        """
        return self.__data
    
    def validate(self, target_properties:list)->object:
        """
        모든 Pandas 데이터가 target_properties에 명시된 속성을 가지고 있는지 확인합니다.
        만일, 속성이 매칭되지 않으면 예외가 발생할 것입니다.
        모든 과정이 성공하면 True를 반환합니다.
        """
        for data_key, _ in self.__data.items():
            self.__data[data_key][target_properties]
        return True

############################################################################################################

class KRXStockData:
    pass

############################################################################################################

class DataVisualization:
    pass

############################################################################################################

# %% [markdown]
# <br><br><br>

# %% [markdown]
# # [ 4 ] Stock Predictions

# %% [markdown]
# ## 01. 데이터 수집 및 전처리 단계

# %% [markdown]
# ### (1) 데이터 경로 및 이름 설정

# %%
# CSV 파일 루트 경로
root_dir:str = os.path.join(".", "data\\주식")

# CSV 파일 전체 경로 및 이름 형식
filepath_form:str = os.path.join(root_dir, "{0}","{0}_{1}.csv")

# 각 CSV 파일들을 가져오기 위한 프로파일 list<dict[]>
csv_file_profiles : list = [
    {
        "name" : "[유가증권]일별 시세정보(주문번호-1300-27)",
        "date_range" : [202001, 202003]
    },
    {
        "name" : "[유가증권]일별 시세정보(주문번호-1300-30)",
        "date_range" : [202101, 202103]
    },
    {
        "name" : "[유가증권]일별 시세정보(주문번호-1300-33)",
        "date_range" : [202201, 202203]
    }
]

# 데이터 전처리에 필요한 속성들
selected_properties = ["거래일자","종목코드","종목명", "시가", "고가", "저가", "종가", "거래량", "업종구분", "PER", "상장일", "시가총액"]

# %% [markdown]
# ### (2) CSV 파일 데이터 불러오기

# %%
# class<PandasBasedCSVHandler> 인스턴스 생성
csv_handler:PandasBasedCSVHandler = PandasBasedCSVHandler(pd)

# %%
# CSV 프로파일 기반으로 class<PandasBasedCSVHandler> 인스턴스에 데이터 병합
for csv_file_info in csv_file_profiles: # 프로파일 요소 기반 iteration 작업
    for date_num in Utils.generate_int_range(csv_file_info["date_range"][0], csv_file_info["date_range"][1]): # Iterator 생성
        csv_handler.take_data_from_CSV_file(
            data_id = date_num, # Year + Month 형식의 정수
            filepath = filepath_form.format(csv_file_info["name"], date_num), # 폴더를 포함한 전체 경로의 파일명
            encoding="cp949" # 파일 인코딩 명시
        )

# %% [markdown]
# ### (3) 데이터 속성 검증하기

# %%
# 검증할 속성 내용들은 [1. 데이터 경로 및 이름 설정]의 selected_properties 변수 참고
csv_handler.validate(selected_properties)
# Out:
# True

# %% [markdown]
# #### - 핸들러(Hander)에 저장된 CSV 데이터 형식
#
# ```js
# {
#     202001 : Pandas,
#     202002 : Pandas,
#     202003 : Pandas,
#     202101 : Pandas,
#     202102 : Pandas,
#     202103 : Pandas,
#     202201 : Pandas,
#     202202 : Pandas,
#     202203 : Pandas
# }
# ```

# %%
csv_handler.get_CSV_data()[202001][selected_properties]
# Out:
#            거래일자          종목코드          종목명    시가    고가    저가    종가     거래량  \
# 0      20200102  KR7000020008      동화약품보통주  8340  8400  8290  8400  111305
# 1      20200103  KR7000020008      동화약품보통주  8400  8450  8290  8360   96437
# 2      20200106  KR7000020008      동화약품보통주  8290  8330  8120  8180   73230
# 3      20200107  KR7000020008      동화약품보통주  8200  8280  8090  8160  117904
# 4      20200108  KR7000020008      동화약품보통주  8170  8170  7830  7930  263246
# ...         ...           ...          ...   ...   ...   ...   ...     ...
# 18322  20200123  KYG5307W1015  엘브이엠씨홀딩스보통주  4220  4325  4200  4290  178258
# 18323  20200128  KYG5307W1015  엘브이엠씨홀딩스보통주  4050  4200  3740  4095  348080
# 18324  20200129  KYG5307W1015  엘브이엠씨홀딩스보통주  4095  4180  4095  4105  104726
# 18325  20200130  KYG5307W1015  엘브이엠씨홀딩스보통주  4100  4145  3985  4050  145074
# 18326  20200131  KYG5307W1015  엘브이엠씨홀딩스보통주  4000  4250  4000  4085  193650
#
#           업종구분    PER       상장일          시가총액
# 0      의약품 제조업  23.01  19760324  234624348000
# 1      의약품 제조업   22.9  19760324  233507089200
# 2      의약품 제조업  22.41  19760324  228479424600
# 3      의약품 제조업  22.36  19760324  227920795200
# 4      의약품 제조업  21.73  19760324  221496557100
# ...        ...    ...       ...           ...
# 18322  자동차 판매업      -  20101130  219306683310
# 18323  자동차 판매업      -  20101130  209338197705
# 18324  자동차 판매업      -  20101130  209849402095
# 18325  자동차 판매업      -  20101130  207037777950
# 18326  자동차 판매업      -  20101130  208826993315
#
# [18327 rows x 12 columns]

# %% [markdown]
# ### (4)

# %% [markdown]
# #### KRX 종목을 기준으로 데이터 분리
#
# ```js
# ```

# %%
csv_data = csv_handler.get_CSV_data()
csv_data[202002]
# Out:
#            거래일자 시장ID          종목코드          종목명    시가    고가    저가    종가  \
# 0      20200203  STK  KR7000020008      동화약품보통주  7790  7840  7370  7530
# 1      20200204  STK  KR7000020008      동화약품보통주  7550  7640  7530  7600
# 2      20200205  STK  KR7000020008      동화약품보통주  7640  7770  7630  7680
# 3      20200206  STK  KR7000020008      동화약품보통주  7750  7890  7690  7750
# 4      20200207  STK  KR7000020008      동화약품보통주  7750  7790  7580  7670
# ...         ...  ...           ...          ...   ...   ...   ...   ...
# 18324  20200224  STK  KYG5307W1015  엘브이엠씨홀딩스보통주  4835  5070  4770  5070
# 18325  20200225  STK  KYG5307W1015  엘브이엠씨홀딩스보통주  5080  5150  4970  5070
# 18326  20200226  STK  KYG5307W1015  엘브이엠씨홀딩스보통주  5050  5130  4980  5040
# 18327  20200227  STK  KYG5307W1015  엘브이엠씨홀딩스보통주  5000  5110  4850  4940
# 18328  20200228  STK  KYG5307W1015  엘브이엠씨홀딩스보통주  4800  4960  4540  4680
#
#           거래량        거래대금  ...  주문량기준취소율  종목별거래횟수기준매수매도불균형 종목별거래량기준매수매도불균형  \
# 0      394550  2967584650  ...  0.352018          0.380111        0.436301
# 1       87815   666582090  ...  0.367710          0.660454        0.487321
# 2      120557   925304910  ...  0.383564          0.508726        0.434874
# 3      116790   909542280  ...  0.353751          0.433333        0.462323
# 4      182278  1399518850  ...  0.319877          0.323601        0.317865
# ...       ...         ...  ...       ...               ...             ...
# 18324  435177  2138539185  ...  0.175747          0.523097        0.572139
# 18325  234995  1189625830  ...  0.207188          0.530172        0.462496
# 18326  217641  1099346705  ...  0.165647          0.375212        0.297810
# 18327  279812  1396515140  ...  0.216348          0.354447        0.210917
# 18328  466537  2226951065  ...  0.203008          0.396070        0.330409
#
#       주문횟수기준주문불균형  주문량기준주문불균형   평균호가스프레드  평균비율스프레드   평균유효스프레드   평균실현스프레드  \
# 0        1.402451    0.859184  14.635436  0.192036  17.111547   0.303962
# 1        0.889005    0.950656  12.786766  0.170271  13.298217   6.397621
# 2        0.945687    0.911906  12.402631  0.168878  15.636998  -2.842870
# 3        1.338227    1.023081  16.000567  0.181895  18.468254   7.411765
# 4        1.582620    0.779785  18.445407  0.243364  29.355231  16.950221
# ...           ...         ...        ...       ...        ...        ...
# 18324    1.992132    1.014681  13.430841  0.229276  12.694611  -4.667135
# 18325    0.954404    0.894499  17.561368  0.247898  13.300493  -2.688278
# 18326    1.407659    0.767952  13.510749  0.270839  16.419205   7.811951
# 18327    1.103750    0.712317  21.297175  0.262642  13.877159  -1.620339
# 18328    1.255567    0.733771  19.745822  0.265583  15.614135  -0.176849
#
#         HS 역선택비용
# 0      16.807585
# 1       6.900596
# 2      18.479868
# 3      11.056489
# 4      12.405010
# ...          ...
# 18324  17.361746
# 18325  15.988771
# 18326   8.607254
# 18327  15.497498
# 18328  15.790984
#
# [18329 rows x 58 columns]

# %%
for _, data_value in csv_data.items():
    selected_df = data_value[selected_properties]
    corps_id = selected_df[["종목코드","종목명"]].drop_duplicates()
    print(id(selected_df), id(corps_id))
    break
    
indicator = Utils.clone(selected_df)
# Out:
# 3058637421152 3058640331680

# %%
indicator.tail()
# Out:
#            거래일자          종목코드          종목명    시가    고가    저가    종가     거래량  \
# 18322  20200123  KYG5307W1015  엘브이엠씨홀딩스보통주  4220  4325  4200  4290  178258
# 18323  20200128  KYG5307W1015  엘브이엠씨홀딩스보통주  4050  4200  3740  4095  348080
# 18324  20200129  KYG5307W1015  엘브이엠씨홀딩스보통주  4095  4180  4095  4105  104726
# 18325  20200130  KYG5307W1015  엘브이엠씨홀딩스보통주  4100  4145  3985  4050  145074
# 18326  20200131  KYG5307W1015  엘브이엠씨홀딩스보통주  4000  4250  4000  4085  193650
#
#           업종구분 PER       상장일          시가총액
# 18322  자동차 판매업   -  20101130  219306683310
# 18323  자동차 판매업   -  20101130  209338197705
# 18324  자동차 판매업   -  20101130  209849402095
# 18325  자동차 판매업   -  20101130  207037777950
# 18326  자동차 판매업   -  20101130  208826993315

# %%
import datetime
pd.to_datetime(indicator["거래일자"].astype('str'))
# Out:
# 0       2020-01-02
# 1       2020-01-03
# 2       2020-01-06
# 3       2020-01-07
# 4       2020-01-08
#            ...
# 18322   2020-01-23
# 18323   2020-01-28
# 18324   2020-01-29
# 18325   2020-01-30
# 18326   2020-01-31
# Name: 거래일자, Length: 18327, dtype: datetime64[ns]

# %%
indicator.loc[indicator["종목코드"] == "KR7000020008"]
# Out:
#         거래일자          종목코드      종목명    시가    고가    저가    종가     거래량     업종구분  \
# 0   20200102  KR7000020008  동화약품보통주  8340  8400  8290  8400  111305  의약품 제조업
# 1   20200103  KR7000020008  동화약품보통주  8400  8450  8290  8360   96437  의약품 제조업
# 2   20200106  KR7000020008  동화약품보통주  8290  8330  8120  8180   73230  의약품 제조업
# 3   20200107  KR7000020008  동화약품보통주  8200  8280  8090  8160  117904  의약품 제조업
# 4   20200108  KR7000020008  동화약품보통주  8170  8170  7830  7930  263246  의약품 제조업
# 5   20200109  KR7000020008  동화약품보통주  8020  8060  7900  7900   50346  의약품 제조업
# 6   20200110  KR7000020008  동화약품보통주  7970  8140  7880  8100   77059  의약품 제조업
# 7   20200113  KR7000020008  동화약품보통주  8140  8250  8070  8220   91646  의약품 제조업
# 8   20200114  KR7000020008  동화약품보통주  8240  8240  8070  8140  100901  의약품 제조업
# 9   20200115  KR7000020008  동화약품보통주  8160  8170  8000  8090   72255  의약품 제조업
# 10  20200116  KR7000020008  동화약품보통주  8140  8140  8030  8030   80537  의약품 제조업
# 11  20200117  KR7000020008  동화약품보통주  8040  8130  8030  8110   47098  의약품 제조업
# 12  20200120  KR7000020008  동화약품보통주  8140  8340  8100  8240  205611  의약품 제조업
# 13  20200121  KR7000020008  동화약품보통주  8250  8280  8080  8130  161270  의약품 제조업
# 14  20200122  KR7000020008  동화약품보통주  8160  8470  8160  8290  251732  의약품 제조업
# 15  20200123  KR7000020008  동화약품보통주  8390  8410  8290  8350   90264  의약품 제조업
# 16  20200128  KR7000020008  동화약품보통주  8400  8960  8290  8590  915591  의약품 제조업
# 17  20200129  KR7000020008  동화약품보통주  8640  8690  8110  8150  370187  의약품 제조업
# 18  20200130  KR7000020008  동화약품보통주  8180  8260  7990  8000  239447  의약품 제조업
# 19  20200131  KR7000020008  동화약품보통주  8030  8110  7880  7910  255775  의약품 제조업
#
#       PER       상장일          시가총액
# 0   23.01  19760324  234624348000
# 1    22.9  19760324  233507089200
# 2   22.41  19760324  228479424600
# 3   22.36  19760324  227920795200
# 4   21.73  19760324  221496557100
# 5   21.64  19760324  220658613000
# 6   22.19  19760324  226244907000
# 7   22.52  19760324  229596683400
# 8    22.3  19760324  227362165800
# 9   22.16  19760324  225965592300
# 10     22  19760324  224289704100
# 11  22.22  19760324  226524221700
# 12  22.58  19760324  230155312800
# 13  22.27  19760324  227082851100
# 14  22.71  19760324  231551886300
# 15  22.88  19760324  233227774500
# 16  23.53  19760324  239931327300
# 17  22.33  19760324  227641480500
# 18  21.92  19760324  223451760000
# 19  21.67  19760324  220937927700

# %% [markdown]
# <hr><hr><hr><hr><hr><hr><hr><hr><hr><hr><hr>

# %%
import random
import datetime

start_date = datetime.datetime.strptime(str(20210406), '%Y%m%d') 

def randomly(start=0, end=100):
    for _ in range(30):
        yield random.randrange(start, end)

raw_data = {
            'Date': [start_date.date() + datetime.timedelta(i) for i in range(30)],
            'Open': list(randomly()),
            'High': list(randomly()),
            'Low': list(randomly()),
            'Close': list(randomly()),
            'Volume': list(randomly(start=1000, end=10000))
           }

raw_df = pd.DataFrame(raw_data)

# %%
raw_df.tail()
# Out:
#           Date  Open  High  Low  Close  Volume
# 25  2021-05-01    27    65   44      6    4490
# 26  2021-05-02     1    44   40     14    2761
# 27  2021-05-03    95    90    0     80    7968
# 28  2021-05-04    27    22   69      3    8077
# 29  2021-05-05    97     2   62     61    7780

# %%
start_date = datetime.datetime.strptime(str(20210506), '%Y%m%d') 

raw_data2 = {
            'Date': [start_date.date() + datetime.timedelta(i) for i in range(30)],
            'Open': list(randomly()),
            'High': list(randomly()),
            'Low': list(randomly()),
            'Close': list(randomly()),
            'Volume': list(randomly(start=1000, end=10000))
           }

raw_df2 = pd.DataFrame(raw_data2)

# %%
raw_df2.head()
# Out:
#          Date  Open  High  Low  Close  Volume
# 0  2021-05-06    14    40   90     26    3061
# 1  2021-05-07    85    16   37     33    9718
# 2  2021-05-08    41    10   28     86    8697
# 3  2021-05-09    22    56   63     76    5928
# 4  2021-05-10    63    73   52     95    1654

# %%
concated = pd.concat([raw_df, raw_df2], ignore_index=True)

# %%
a = concated[["Date","Close"]]

# %%
print(id(concated), id(a))
# Out:
# 3058640332352 3058640334176

# %%
import pandas
import numpy

class StockAnalyzer:
    """
    주식 분석에 필요한 계산 및 분석을 위한 클래스입니다.
    모든 함수들은 모듈 pandas에 대한 의존성을 가집니다.
    """
    @staticmethod
    def RSI_calculation(values)->float:
        """
        Calculation of Relative Strength Index (RSI)     
        Avg(PriceUp)/(Avg(PriceUP)+Avg(PriceDown)*100
        Where: PriceUp(t)=1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)>0};
               PriceDown(t)=-1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)<0};
        """
        up = values[values>0].mean()
        down = -1*values[values<0].mean()
        return 100 * up / (up + down)
    
    # as_of_property 수정 필요
    @staticmethod
    def add_Momentum_1D(ins_ref:pandas, as_of_property:str)->pandas:
        """
        Add Momentum_1D column for all 15 stocks.
        Momentum_1D = P(t) - P(t-1)
        """
        ins_ref['Momentum_1D'] = (ins_ref[as_of_property]-ins_ref[as_of_property].shift(1)).fillna(0)
        return ins_ref
    
    @staticmethod
    def add_RSI_14D(ins_ref:pandas)->pandas:
        """
        Calculation of Relative Strength Index (RSI)
        """
        ins_ref['RSI_14D'] = ins_ref['Momentum_1D'].rolling(center=False, window=14).apply(StockAnalyzer.RSI_calculation).fillna(0)
        return ins_ref
        
    @staticmethod
    def bollinger_bands_calculation(price:int, length:int=30, numsd:int=2)->float:
        """ 
        Calculation of Bollinger Bands
        returns average, upper band, and lower band
        """
        ave = price.rolling(window = length, center = False).mean()
        sd = price.rolling(window = length, center = False).std()
        upband = ave + (sd*numsd)
        dnband = ave - (sd*numsd)
        print(type(numpy.round(ave,3)), type(numpy.round(upband,3)), type(numpy.round(dnband,3)))
        return numpy.round(ave,3), numpy.round(upband,3), numpy.round(dnband,3)
        
    # as_of_property 수정 필요
    @staticmethod
    def add_BB_Band(ins_ref:pandas, as_of_property:str)->pandas:
        ins_ref['BB_Middle_Band'], ins_ref['BB_Upper_Band'], ins_ref['BB_Lower_Band'] = StockAnalyzer.bollinger_bands_calculation(ins_ref[as_of_property], length=20, numsd=1)
        ins_ref['BB_Middle_Band'] = ins_ref['BB_Middle_Band'].fillna(0)
        ins_ref['BB_Upper_Band'] = ins_ref['BB_Upper_Band'].fillna(0)
        ins_ref['BB_Lower_Band'] = ins_ref['BB_Lower_Band'].fillna(0)
        return ins_ref

    # Date, High, Low 수정 필요
    @staticmethod
    def aroon_oscillator_calculation(df, tf=25):  
        """
        Calculation of Aroon Oscillator
        return type of tuple<list<float>>
        """
        aroonup = []
        aroondown = []
        x = tf
        while x < len(df['Date']):
            aroon_up = ((df['High'][x-tf:x].tolist().index(max(df['High'][x-tf:x])))/float(tf))*100
            aroon_down = ((df['Low'][x-tf:x].tolist().index(min(df['Low'][x-tf:x])))/float(tf))*100
            aroonup.append(aroon_up)
            aroondown.append(aroon_down)
            x+=1
        return aroonup, aroondown
    
    @staticmethod
    def add_aroon_oscillator(ins_ref:pandas)->pandas:
        """
        """
        list_of_zeros = [0] * 25
        up, down = StockAnalyzer.aroon_oscillator_calculation(ins_ref)
        aroon_list = [x - y for x, y in zip(up,down)]
        if len(aroon_list) == 0:
            aroon_list = [0] * ins_ref.shape[0]
            ins_ref['Aroon_Oscillator'] = aroon_list
        else:
            ins_ref['Aroon_Oscillator'] = list_of_zeros + aroon_list
        return ins_ref

    # Close, Volume 수정 필요
    @staticmethod
    def add_PVT(ins_ref:pandas)->pandas:
        """
        Calculation of Price Volume Trend
        PVT = [((CurrentClose - PreviousClose) / PreviousClose) x Volume] + PreviousPVT
        """
        ins_ref["PVT"] = (ins_ref['Momentum_1D']/ ins_ref['Close'].shift(1)) * ins_ref['Volume']
        ins_ref["PVT"] = ins_ref["PVT"] - ins_ref["PVT"].shift(1)
        ins_ref["PVT"] = ins_ref["PVT"].fillna(0)
        return ins_ref
    
    # Close, High, Low 수정필요
    @staticmethod
    def add_AB_Band(ins_ref:pandas)->pandas:
        """
        Calculation of Acceleration Bands
        """
        #ins_ref['AB_Middle_Band'] = pd.rolling_mean(df['Close'], 20)
        ins_ref['AB_Middle_Band'] = ins_ref['Close'].rolling(window = 20, center=False).mean()
        # High * ( 1 + 4 * (High - Low) / (High + Low))
        ins_ref['aupband'] = ins_ref['High'] * (1 + 4 * (ins_ref['High']-ins_ref['Low'])/(ins_ref['High']+ins_ref['Low']))
        ins_ref['AB_Upper_Band'] = ins_ref['aupband'].rolling(window=20, center=False).mean()
        # Low *(1 - 4 * (High - Low)/ (High + Low))
        ins_ref['adownband'] = ins_ref['Low'] * (1 - 4 * (ins_ref['High']-ins_ref['Low'])/(ins_ref['High']+ins_ref['Low']))
        ins_ref['AB_Lower_Band'] = ins_ref['adownband'].rolling(window=20, center=False).mean()
        ins_ref = ins_ref.fillna(0)
        return ins_ref

# %%
StockAnalyzer.add_Momentum_1D(raw_df, "Close")
StockAnalyzer.add_RSI_14D(raw_df).tail(5)
# Out:
#           Date  Open  High  Low  Close  Volume  Momentum_1D    RSI_14D
# 25  2021-05-01    27    65   44      6    4490        -70.0  59.800664
# 26  2021-05-02     1    44   40     14    2761          8.0  56.270329
# 27  2021-05-03    95    90    0     80    7968         66.0  61.797027
# 28  2021-05-04    27    22   69      3    8077        -77.0  54.691076
# 29  2021-05-05    97     2   62     61    7780         58.0  53.846154

# %%
StockAnalyzer.add_BB_Band(raw_df, "Close").tail(5)
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>
#           Date  Open  High  Low  Close  Volume  Momentum_1D    RSI_14D  \
# 25  2021-05-01    27    65   44      6    4490        -70.0  59.800664
# 26  2021-05-02     1    44   40     14    2761          8.0  56.270329
# 27  2021-05-03    95    90    0     80    7968         66.0  61.797027
# 28  2021-05-04    27    22   69      3    8077        -77.0  54.691076
# 29  2021-05-05    97     2   62     61    7780         58.0  53.846154
#
#     BB_Middle_Band  BB_Upper_Band  BB_Lower_Band
# 25           61.60         86.532         36.668
# 26           60.70         87.042         34.358
# 27           60.00         85.586         34.414
# 28           57.75         86.258         29.242
# 29           58.40         86.822         29.978

# %%
StockAnalyzer.add_aroon_oscillator(raw_df).tail()
# Out:
#           Date  Open  High  Low  Close  Volume  Momentum_1D    RSI_14D  \
# 25  2021-05-01    27    65   44      6    4490        -70.0  59.800664
# 26  2021-05-02     1    44   40     14    2761          8.0  56.270329
# 27  2021-05-03    95    90    0     80    7968         66.0  61.797027
# 28  2021-05-04    27    22   69      3    8077        -77.0  54.691076
# 29  2021-05-05    97     2   62     61    7780         58.0  53.846154
#
#     BB_Middle_Band  BB_Upper_Band  BB_Lower_Band  Aroon_Oscillator
# 25           61.60         86.532         36.668             -52.0
# 26           60.70         87.042         34.358             -52.0
# 27           60.00         85.586         34.414             -52.0
# 28           57.75         86.258         29.242             -52.0
# 29           58.40         86.822         29.978              44.0

# %%
StockAnalyzer.add_PVT(raw_df).tail()
# Out:
#           Date  Open  High  Low  Close  Volume  Momentum_1D    RSI_14D  \
# 25  2021-05-01    27    65   44      6    4490        -70.0  59.800664
# 26  2021-05-02     1    44   40     14    2761          8.0  56.270329
# 27  2021-05-03    95    90    0     80    7968         66.0  61.797027
# 28  2021-05-04    27    22   69      3    8077        -77.0  54.691076
# 29  2021-05-05    97     2   62     61    7780         58.0  53.846154
#
#     BB_Middle_Band  BB_Upper_Band  BB_Lower_Band  Aroon_Oscillator  \
# 25           61.60         86.532         36.668             -52.0
# 26           60.70         87.042         34.358             -52.0
# 27           60.00         85.586         34.414             -52.0
# 28           57.75         86.258         29.242             -52.0
# 29           58.40         86.822         29.978              44.0
#
#               PVT
# 25   -8857.126316
# 26    7816.859649
# 27   33882.095238
# 28  -45337.541071
# 29  158187.445833

# %%
StockAnalyzer.add_AB_Band(raw_df).tail()
# Out:
#           Date  Open  High  Low  Close  Volume  Momentum_1D    RSI_14D  \
# 25  2021-05-01    27    65   44      6    4490        -70.0  59.800664
# 26  2021-05-02     1    44   40     14    2761          8.0  56.270329
# 27  2021-05-03    95    90    0     80    7968         66.0  61.797027
# 28  2021-05-04    27    22   69      3    8077        -77.0  54.691076
# 29  2021-05-05    97     2   62     61    7780         58.0  53.846154
#
#     BB_Middle_Band  BB_Upper_Band  BB_Lower_Band  Aroon_Oscillator  \
# 25           61.60         86.532         36.668             -52.0
# 26           60.70         87.042         34.358             -52.0
# 27           60.00         85.586         34.414             -52.0
# 28           57.75         86.258         29.242             -52.0
# 29           58.40         86.822         29.978              44.0
#
#               PVT  AB_Middle_Band     aupband  AB_Upper_Band   adownband  \
# 25   -8857.126316           61.60  115.091743     103.219048   10.091743
# 26    7816.859649           60.70   52.380952     100.768002   32.380952
# 27   33882.095238           60.00  450.000000     122.568983   -0.000000
# 28  -45337.541071           57.75  -23.450549     122.656659  211.549451
# 29  158187.445833           58.40   -5.500000     119.655572  294.500000
#
#     AB_Lower_Band
# 25      53.469048
# 26      54.268002
# 27      52.318983
# 28      46.156659
# 29      56.655572

# %%
columns_to_drop = ['Momentum_1D', 'aupband', 'adownband']
raw_df = raw_df.drop(labels = columns_to_drop, axis=1)
raw_df.head()
# Out:
#          Date  Open  High  Low  Close  Volume  RSI_14D  BB_Middle_Band  \
# 0  2021-04-06    94    55   96     83    5635      0.0             0.0
# 1  2021-04-07    24    14   36     25    3998      0.0             0.0
# 2  2021-04-08    36    78   19     61    8772      0.0             0.0
# 3  2021-04-09    31    97   42     76    3786      0.0             0.0
# 4  2021-04-10    89    86   38     72    7919      0.0             0.0
#
#    BB_Upper_Band  BB_Lower_Band  Aroon_Oscillator           PVT  \
# 0            0.0            0.0               0.0      0.000000
# 1            0.0            0.0               0.0      0.000000
# 2            0.0            0.0               0.0  15425.463133
# 3            0.0            0.0               0.0 -11700.696393
# 4            0.0            0.0               0.0  -1347.773080
#
#    AB_Middle_Band  AB_Upper_Band  AB_Lower_Band
# 0             NaN            NaN            NaN
# 1             NaN            NaN            NaN
# 2             NaN            NaN            NaN
# 3             NaN            NaN            NaN
# 4             NaN            NaN            NaN

# %% [markdown]
# visualization

# %% [markdown]
# # 정리
#
# ## 파라미터
#  - (Required)시가, 종가, 고가, 저가, Volume
#  - (Optional)RSI, AROON, ...
#  - (Optional)금리, 환율
#  - Visualization
#
# 시가, 종가, 고가, 저가, Volume
#
# ## Process
#
#  1. 데이터 정규화
#  2. 데이터 전처리
#  3. 데이터 시각화
#
#  4. 인공지능 학습
#  5. 결과 분석 및 최적화
#  6. (4-5)은 몇 번 반복
#
#  7. 비즈니스 모델 제안

# %%
# 변수 이름을 loop 돌려서 할당
for date in csv_data.keys():
    globals()[f'data_{date}'] = csv_data[date]
    globals()[f'data_{date}_names'] = list(csv_data[date]['종목명'].unique())

# %%
years = [2020, 2021, 2022]

# %%
data_2020 = pd.concat([globals()[f'data_{date}'] for date in list(csv_data.keys())[:3]], ignore_index=True)
data_2021 = pd.concat([globals()[f'data_{date}'] for date in list(csv_data.keys())[3:6]], ignore_index=True)
data_2022 = pd.concat([globals()[f'data_{date}'] for date in list(csv_data.keys())[6:]], ignore_index=True)

# %%
for year in years:
    globals()[f'data_{year}_names'] = globals()[f'data_{year}']['종목명'].unique()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import plotly
from tqdm import tqdm
import FinanceDataReader as fdr

from sklearn.cluster import KMeans
from sklearn.preprocessing import Normalizer, MinMaxScaler, StandardScaler, RobustScaler

# %%
scaler_minmax = MinMaxScaler()
scaler_standard = StandardScaler()
normalizer = Normalizer()
seed = 42

# %%
x = []
names = []
w = 5
n = 61

for stock_item in tqdm(range(len(data_2020_names))):
    _df = data_2020.loc[data_2020['종목명'] == data_2020_names[stock_item]]
    # print(_df)

    if len(_df) < n:
        continue

    _df = _df.sort_values(by='거래일자', ascending=True)
    # print(_df)
    _df['x'] = _df['종가'] / _df.iloc[0]['종가'] - 1
    # print(_df)

    if len(_df) < n:
        continue

    _df['x'] = pd.Series(_df['x']).rolling(w).mean()
    x.append(_df['x'].tolist()[w-1:])
    names.append(data_2020_names[stock_item])

krx_X = np.array(x)
krx_names = np.array(names)
# Out:
# 100%|██████████| 926/926 [00:05<00:00, 165.29it/s]

# %%
def kmeans_model(x, n_clusters, scaler, seed=42):
    # n_clusters = n_clusters
    # scaler = scaler
    model = KMeans(n_clusters=n_clusters, random_state=seed, init='random')
    model.fit(scaler.fit_transform(x))

    from collections import Counter
    print(Counter(model.labels_))

    return model

# %%
krx_model = kmeans_model(x=krx_X, n_clusters=15, scaler=normalizer)
# Out:
# Counter({13: 190, 6: 173, 4: 113, 8: 110, 9: 70, 11: 59, 12: 43, 14: 37, 2: 28, 1: 23, 3: 22, 10: 14, 5: 12, 0: 7, 7: 4})

# %%
krx_names[krx_model.labels_ == 0]
# Out:
# array(['부광약품보통주', '씨아이테크보통주', '파미셀보통주', '일양약품보통주', '진원생명과학보통주',
#        '대성홀딩스보통주', '신풍제약보통주'], dtype='<U33')

# %%
def cluster_itmes(model, names, k):
    cluster = {}
    for label in range(k):
        cluster[label] = names[model.labels_ == label]
    return cluster

krx_cluster_names = cluster_itmes(krx_model, krx_names, 15)

# %%
krx_cluster_names
# Out:
# {0: array(['부광약품보통주', '씨아이테크보통주', '파미셀보통주', '일양약품보통주', '진원생명과학보통주',
#         '대성홀딩스보통주', '신풍제약보통주'], dtype='<U33'),
#  1: array(['씨제이대한통운보통주', '조선내화보통주', '현대해상화재보험보통주', '동양보통주', 'SK네트웍스보통주',
#         '남영비비안보통주', '조흥보통주', '동양물산기업보통주', '쌍용양회공업보통주', '신흥보통주', '녹십자보통주',
#         '대양금속보통주', '한올바이오파마보통주', '지코보통주', '한화갤러리아타임월드보통주', '웅진씽크빅 보통주',
#         '한진중공업 보통주', '비티원보통주', '이마트보통주', '동아에스티보통주', '코스맥스보통주',
#         '금호에이치티보통주', '동아타이어공업보통주'], dtype='<U33'),
#  2: array(['KR모터스보통주', '흥국화재해상보험1우선주', '한진보통주', '오리엔트바이오보통주', '국제약품보통주',
#         '일성신약보통주', '동방보통주', '농심보통주', '깨끗한나라보통주', '덕성1우선주', '삼성SDI보통주',
#         '삼성SDI1우선주', '남선알미늄보통주', 'CJ씨푸드보통주', '모나리자보통주', '신풍제약1우선주',
#         'MH에탄올보통주', '디피씨보통주', '카카오보통주', '엔씨소프트보통주', 'LG화학보통주',
#         '하나유비에스암바토비니켈해외자원개발2호', '한진칼보통주', '삼성바이오로직스보통주', '넷마블보통주',
#         '센트랄모텍보통주', '현대에너지솔루션보통주', '두산솔루스1우선주'], dtype='<U33'),
#  3: array(['하이트진로보통주', '하이트진로홀딩스보통주', '유진투자증권보통주', 'SH에너지화학보통주', '한국화장품제조보통주',
#         '한국석유공업보통주', '우리들제약보통주', '롯데지주1우선주', '남선알미늄1우선주', '한샘보통주',
#         '웰바이오텍보통주', '극동유화보통주', '한솔케미칼보통주', '애경산업보통주', '서원보통주',
#         '신세계인터내셔날보통주', '체시스보통주', '신세계아이앤씨 보통주', '우리들휴브레인보통주', '코오롱머티리얼보통주',
#         '쿠쿠홀딩스보통주', '오리온보통주'], dtype='<U33'),
#  4: array(['하이트진로2우선주(신형)', '하이트진로홀딩스1우선주', '두산1우선주', '두산2우선주(신형)', '대동공업보통주',
#         '영풍보통주', '한국주철관공업보통주', '부국증권보통주', '부국증권1우선주', '에스지충방 보통주',
#         'BYC1우선주', '대상1우선주', '신영증권1우선주', '삼양통상보통주', '한일철강보통주', '한국제지보통주',
#         '세기상사보통주', '동일제강보통주', 'TCC스틸보통주', '진흥기업보통주', '신풍제지보통주', '대유에이텍',
#         '혜인보통주', '한화투자증권보통주', '한화투자증권1우선주', 'IHQ보통주', '진양산업보통주',
#         '에스지세계물산보통주', '태양금속공업보통주', 'NPC보통주', 'NPC1우선주', '남성보통주',
#         '현대비앤지스틸1우선주', '디알비동일보통주', '삼진제약보통주', '넥센보통주', '넥센1우선주',
#         '크라운해태홀딩스보통주', '크라운해태홀딩스1우선주', '원림보통주', '엔에이치투자증권1우선주',
#         '한국전자홀딩스보통주', 'GS건설보통주', '인스코비보통주', '대림통상보통주', '지에스리테일보통주',
#         '일신석재보통주', '에이프로젠케이아이씨보통주', '선도전기보통주', '이수페타시스보통주', '사조동아원보통주',
#         '대동전자보통주', '아남전자보통주', '동양철관보통주', 'KCTC 보통주', '광동제약보통주',
#         '진양폴리우레탄보통주', '화신보통주', '퍼스텍보통주', '유니켐보통주', '신성이엔지보통주', '화승알앤에이보통주',
#         '성문전자보통주', '대창단조보통주', '에이엔피보통주', '광전자보통주', '조일알미늄보통주', '한국종합기술보통주',
#         '인지컨트롤스보통주', 'WISCOM보통주', '한국콜마홀딩스보통주', '대원화성보통주', '한솔홈데코보통주',
#         '마니커보통주', '케이티비투자증권보통주', '콤텍시스템보통주', '황금에스티보통주', '자화전자보통주',
#         '세종공업보통주', '두산중공업보통주', '광주신세계보통주', '상신브레이크보통주', '대우건설보통주',
#         '유니온머티리얼보통주', '동원F&B보통주', '한국전력기술 보통주', '케이티스카이라이프', '테이팩스보통주',
#         '한국투자금융지주보통주', '하이스틸 보통주', '코아스보통주', '농심홀딩스보통주', '일진다이아몬드 보통주',
#         '그린케미칼보통주', '맥쿼리한국인프라투융자회사 보통주', '케이이씨 보통주', '기신정기 보통주',
#         '형지엘리트보통주', 'AJ네트웍스보통주', '해태제과식품주식회사', '락앤락보통주', '케이씨코트렐보통주',
#         'DSR보통주', '한국투자Parallel유전해외자원개발특별자산투자회사1호', '종근당보통주', '서연이화보통주',
#         '만도보통주', '한솔제지보통주', '엘에스전선아시아보통주', '화승엔터프라이즈보통주', 'BGF리테일보통주',
#         '자이에스앤디보통주', '두산퓨얼셀1우선주'], dtype='<U33'),
#  5: array(['한진중공업홀딩스보통주', '조광피혁보통주', '국동보통주', '신한보통주', '일양약품1우선주',
#         '폴루스바이오팜보통주', '키위미디어그룹보통주', '세원정공보통주', '주식회사동남합성', '웅진에너지보통주',
#         '컨버즈보통주', '세화아이엠씨보통주'], dtype='<U33'),
#  6: array(['메리츠화재해상보험보통주', '삼양홀딩스1우선주', '두산보통주', '한국테크놀로지그룹보통주', '노루홀딩스보통주',
#         '삼화페인트공업보통주', '가온전선보통주', '천일고속보통주', '삼성화재해상보험1우선주', '강남제비스코보통주',
#         '한화보통주', '유니온보통주', 'CJ보통주', 'CJ1우선주', 'CJ4우선주(전환)', '만호제강보통주',
#         '대한제분보통주', '지에스글로벌보통주', '대한전선보통주', 'BYC보통주', '현대차증권보통주',
#         '케이비아이동국실업보통주', '대상보통주', '신영증권보통주', '알루코 보통주', '코오롱1우선주', '아세아보통주',
#         '도화엔지니어링보통주', '동성제약보통주', '제일파마홀딩스보통주', '삼영무역보통주', '선창산업보통주',
#         '유성기업보통주', '코오롱글로벌보통주', '성보화학보통주', '일신방직보통주', '대한항공보통주',
#         '쌍용자동차보통주', '대한화섬보통주', '남양유업보통주', '남양유업1우선주', '사조대림보통주',
#         '현대제철 보통주', '한솔홀딩스보통주', '세방1우선주', '삼화왕관보통주', '세방전지보통주',
#         '현대비앤지스틸보통주', '효성보통주', '조광페인트보통주', '신라교역보통주', '휴스틸보통주', '부산주공보통주',
#         '동성화학보통주', '롯데칠성음료1우선주', '신성통상보통주', '한국공항보통주', '삼영전자공업보통주',
#         '신영와코루보통주', '풍산홀딩스보통주', '이수화학보통주', '동원산업보통주', '에스케이디스커버리보통주',
#         '제주은행보통주', '대원전선보통주', '삼성공조보통주', '미래에셋대우1우선주', '벽산보통주',
#         '한국특수형강보통주', '디티알오토모티브보통주', '태평양물산보통주', 'NI스틸보통주', '문배철강보통주',
#         '일정실업보통주', '신원1우선주', '무림피앤피보통주', '삼정펄프 보통주', '한국내화보통주',
#         '한국프랜지공업보통주', '삼호개발 보통주', 'STX보통주', '세우글로벌보통주', '디와이보통주',
#         '계룡건설산업보통주', '금강공업보통주', '영보화학보통주', '사조씨푸드보통주', '한라보통주',
#         '부산도시가스보통주', '예스코홀딩스보통주', '큐로보통주', '태경산업보통주', '대현보통주', '삼성증권보통주',
#         '동부제철보통주', '동부제철1우선주', '한세예스24홀딩스보통주', 'DB금융투자보통주', '퍼시스보통주',
#         '광명전기보통주', '우신시스템보통주', 'E1보통주', '디씨엠보통주', 'KPX케미칼보통주', 'SJM홀딩스보통주',
#         '이구산업보통주', '부국철강 보통주', 'BGF보통주', '팬오션보통주', '신도리코보통주', '제일기획보통주',
#         '케이티보통주', 'LG디스플레이보통주', '신세계건설', '인천도시가스 보통주', 'SK1우선주',
#         '한국토지신탁보통주', '지투알보통주', 'S&T홀딩스보통주', '하나투어보통주', '대우조선해양보통주',
#         '한미글로벌건축사사무소보통주', '케이티씨에스보통주', '케이티아이에스보통주', 'LG전자보통주', 'LG전자1우선주',
#         '휴켐스보통주', '한국투자금융지주1우선주', '금호타이어보통주', 'STX엔진보통주', 'GS1우선주',
#         'LIG넥스원보통주', '동양생명보험보통주', '대한제강 보통주', '대상홀딩스 보통주', '하나금융지주보통주',
#         '진도 보통주', '노루페인트 보통주', '디아이씨 보통주', '이아이디보통주', 'SK이노베이션 보통주',
#         '진양홀딩스보통주', 'S&TC 보통주', '동성코퍼레이션보통주', '이연제약보통주', '한세실업보통주',
#         '미원홀딩스 보통주', '엘지하우시스', '엘지하우시스 1우선주', '영원무역보통주', '조선선재 보통주',
#         '코오롱인더스트리1우선주', 'SJM보통주', '한전산업개발보통주', '선진보통주', '코오롱플라스틱보통주',
#         'BNK금융지주보통주', '하이골드오션8호국제선박투자회사', 'JB금융지주보통주', '아세아시멘트보통주',
#         '드림텍보통주', '제이에스코퍼레이션보통주', '현대코퍼레이션홀딩스보통주', '두산밥캣보통주', '크라운제과보통주',
#         '제일약품보통주', '한화시스템보통주', 'SK케미칼1우선주', '효성중공업보통주', '세아제강보통주',
#         '두산퓨얼셀보통주', '두산솔루스2우선주(신형)', 'NH프라임리츠보통주'], dtype='<U33'),
#  7: array(['흥국화재해상보험2우선주(신형)', '페이퍼코리아보통주', '셀트리온보통주', 'SK케미칼보통주'],
#        dtype='<U33'),
#  8: array(['성창기업지주보통주', '대림산업1우선주', '기아자동차보통주', '삼일제약보통주', '현대건설보통주',
#         '현대건설1우선주', '화천기공보통주', '보해양조보통주', '상상인증권보통주', '삼성제약', 'SK증권보통주',
#         '조비보통주', '경농보통주', '고려산업보통주', '넥센타이어1우선주(신형)', '범양건영보통주', '삼익악기보통주',
#         '디아이보통주', '유안타증권보통주', 'S&T중공업보통주', '넥스트사이언스보통주', '코리안리재보험보통주',
#         '신세계보통주', '고려개발보통주', '현대약품보통주', '한솔테크닉스보통주', '써니전자보통주',
#         '녹십자홀딩스2우선주(신형)', '포스코보통주', '대림B&Co보통주', '에스엘보통주', '한일현대시멘트보통주',
#         '미래에셋대우', '태경화학보통주', '샘표보통주', '호텔신라보통주', '금비보통주', '신원보통주',
#         '경동나비엔보통주', '한국조선해양보통주', 'OCI보통주', 'LS산전보통주', '삼성중공업보통주',
#         '현대미포조선보통주', '현대위아보통주', '부산산업보통주', '한신기계공업보통주', '현대종합상사보통주',
#         '금호석유화학1우선주', '영흥철강 보통주', '영화금속보통주', '현대모비스보통주', '한화에어로스페이스보통주',
#         'HDC보통주', '일성건설보통주', '백광소재보통주', '일진홀딩스보통주', '환인제약보통주', '신대양제지보통주',
#         '명문제약 보통주', 'SK텔레콤보통주', '대교보통주', '다우기술보통주', '에쓰씨엔지니어링보통주',
#         '제이준코스메틱보통주', '남해화학보통주', '세하보통주', '삼성카드 보통주', '교보증권보통주',
#         '신세계푸드보통주', '롯데관광개발 보통주', '삼성생명보험보통주', '케이티앤지보통주', '무학보통주',
#         '주연테크 보통주', '포스코인터내셔널보통주', '한전KPS 보통주', '현대로템보통주', 'DSR제강보통주',
#         '주식회사 용평리조트', '유엔젤보통주', '에이치에스디엔진보통주', '엔케이 보통주', '아모레퍼시픽 1우선주',
#         'SBS미디어홀딩스보통주', '풍산 보통주', 'KB금융지주 보통주', '호전실업보통주', '그랜드코리아레저보통주',
#         '대성에너지보통주', '대성산업보통주', '한미약품보통주', '인터지스보통주', '시디즈보통주',
#         'DGB금융지주보통주', '케이탑리츠보통주', '바다로19호선박투자회사', '애경유화보통주', '한국콜마보통주',
#         '더블유게임즈보통주', '디와이파워보통주', '잇츠한불보통주', 'JW생명과학보통주', '일동제약보통주',
#         '현대일렉트릭보통주', '미원스페셜티케미칼보통주', '진에어보통주', '케이씨텍보통주', '롯데정보통신보통주',
#         '효성첨단소재보통주'], dtype='<U33'),
#  9: array(['유유제약보통주', '유유제약2우선주(신형)', '대원강업보통주', 'LS네트웍스보통주', '한화1우선주',
#         'DB하이텍보통주', 'JW중외제약1우선주', 'DI동일보통주', '한양증권1우선주', '한국수출포장공업보통주',
#         '아세아제지보통주', '한독보통주', '신일산업보통주', '보락보통주', '미원상사보통주', '유안타증권1우선주',
#         'LG보통주', 'LG1우선주', '한창보통주', '현대자동차보통주', '현대자동차1우선주',
#         '현대자동차2우선주(신형)', '현대자동차3우선주(신형)', '화승인더스트리보통주', '삼아알미늄보통주',
#         '카프로보통주', '우성사료보통주', '코리아써키트1우선주', '윌비스보통주', '무림페이퍼보통주',
#         '케이씨그린홀딩스보통주', '모토닉보통주', '삼성중공업1우선주', '우진아이엔에스보통주', '한솔PNS보통주',
#         '화천기계보통주', '평화홀딩스보통주', '에넥스보통주', '경동인베스트보통주', '경인양행보통주', '이스타코보통주',
#         '두올보통주', '삼성에스디에스보통주', '동원금속보통주', '한온시스템보통주', '티에이치엔보통주',
#         '덕양산업보통주', '동원수산보통주', '아주캐피탈보통주', 'NAVER보통주', '제이콘텐트리보통주',
#         '와이지플러스보통주', '진양화학보통주', '유니퀘스트 보통주', '휴비스보통주', '대상홀딩스 1우선주',
#         '현대글로비스보통주', '동양피스톤보통주', '후성 보통주', '씨제이제일제당 주식회사 1우선주', '쌍방울',
#         '일진전기 보통주', '씨에스윈드보통주', '화인베스틸보통주', '미원화학보통주',
#         '한국투자ANKOR유전해외자원개발특별자산투자회사1호(지분증권)', '동일고무벨트보통주', '이노션보통주',
#         '경보제약보통주', '하나제약보통주'], dtype='<U33'),
#  10: array(['대한방직보통주', '동양2우선주(신형)', '서울식품공업보통주', '서울식품공업1우선주', '사조오양보통주',
#         '미래아이앤지보통주', '한농화성보통주', '키다리스튜디오보통주', '우진플라임 보통주', '종근당바이오보통주',
#         '동북아12호선박투자회사보통주', '동북아13호선박투자회사보통주', '씨제이제일제당 주식회사 보통주',
#         '하나유비에스암바토비니켈해외자원개발1호'], dtype='<U33'),
#  11: array(['경방보통주', '대유플러스보통주', '노루홀딩스1우선주', '흥국화재해상보험보통주', 'CS홀딩스보통주',
#         '유수홀딩스보통주', '한화3우선주(신형)', '삼부토건보통주', 'SK증권1우선주', '동양1우선주',
#         '동양3우선주(신형)', 'SK네트웍스1우선주', '신화실업보통주', '대한제당보통주', '대한제당1우선주',
#         '코오롱글로벌1우선주', '방림보통주', '미창석유공업보통주', '한성기업보통주', '삼천리보통주', '한신공영보통주',
#         '성신양회1우선주', '삼광글라스보통주', '빙그레보통주', '모나미보통주', '동부건설보통주', '동부건설1우선주',
#         '에스케이디스커버리1우선주', '대원전선1우선주', '미래에셋대우2우선주(신형)', '동방아그로보통주',
#         '코리아써키트보통주', '대덕전자보통주', '대덕전자1우선주', '메리츠종합금융증권보통주', 'SIMPAC보통주',
#         '우리종합금융보통주', '고려아연보통주', '현대상선보통주', '태림포장보통주', '동원시스템즈1우선주',
#         '서울도시가스보통주', '풀무원보통주', 'SK가스보통주', '세아특수강보통주', '삼원강재 보통주', '인팩보통주',
#         'LG유플러스보통주', '케이에스에스 해운 보통주', '현대홈쇼핑보통주', 'S&T모티브보통주', '동양고속보통주',
#         '미래에셋생명보험보통주', '노루페인트 1우선주', '미래에셋맵스아시아퍼시픽부동산공모1호', '비상교육 보통주',
#         'SK디앤디보통주', '크라운제과1우선주', '롯데제과보통주'], dtype='<U33'),
#  12: array(['에스케이하이닉스보통주', '한양증권보통주', '진흥기업1우선주(신형)', '진흥기업2우선주(신형)', '덕성보통주',
#         '코스모신소재보통주', '삼성전자보통주', '대구백화점보통주', '영풍제지보통주', '호텔신라1우선주',
#         '삼성전기보통주', '한솔로지스틱스보통주', '참엔지니어링보통주', '삼화전기보통주', 'LG이노텍보통주',
#         '삼화전자공업보통주', '갤럭시아에스엠보통주', 'SKC보통주', '계양전기보통주', '계양전기1우선주',
#         '청호컴넷보통주', '까뮤이앤씨보통주', '지엠비코리아보통주', '지누스보통주', '대영포장보통주',
#         '금강공업1우선주', '한국카본보통주', '삼성물산보통주', '삼성물산1우선주(신형)', '에스비에스보통주',
#         'NICE보통주', 'LG생활건강보통주', 'LG생활건강1우선주', '대호에이엘보통주', '에이블씨엔씨보통주',
#         '평화산업 주식회사 보통주', '현대에이치씨엔보통주', '핸즈코퍼레이션보통주', '한진칼1우선주', '해성디에스보통주',
#         '토니모리보통주', '삼양패키징보통주', '효성티앤씨보통주'], dtype='<U33'),
#  13: array(['동화약품보통주', '삼양홀딩스보통주', '유한양행보통주', '유한양행1우선주', '대림산업보통주',
#         '일동홀딩스보통주', '한화손해보험보통주', '롯데손해보험보통주', '동아쏘시오홀딩스보통주', '이화산업보통주',
#         '삼성화재해상보험보통주', '전방보통주', 'DB하이텍1우선주', 'JW중외제약보통주', 'LG상사보통주',
#         '금호전기보통주', '동국제강보통주', '남광토건보통주', '태원물산보통주', '세아베스틸보통주',
#         '제일연마공업보통주', '대한제당3우선주(신형)', '오리온홀딩스보통주', '삼호보통주', 'KISCO홀딩스보통주',
#         '코오롱보통주', '고려제강보통주', '롯데푸드보통주', '넥센타이어보통주', '주식회사케이씨씨', '화성산업보통주',
#         '아모레G보통주', '아모레G1우선주', '아모레G3우선주(전환)', '한국쉘석유보통주', '금호산업보통주',
#         '금호산업1우선주', '세아제강지주보통주', '대웅보통주', '대원제약보통주', '태광산업보통주', '흥아해운보통주',
#         '한일홀딩스보통주', '쌍용양회공업1우선주', '유화증권보통주', '유화증권1우선주', '영진약품보통주',
#         '대신증권보통주', '대신증권1우선주', '대신증권2우선주(신형)', '보령제약보통주', '롯데정밀화학보통주',
#         '세방보통주', '송원산업보통주', '대림씨엔에스 주식회사', '티웨이홀딩스보통주', '동일산업보통주',
#         '성신양회보통주', '롯데지주보통주', '녹십자홀딩스보통주', '롯데칠성음료보통주', '현대그린푸드보통주',
#         'SPC삼립보통주', 'DB손해보험보통주', '휴니드테크놀러지스보통주', '대한해운보통주', '엔에이치투자증권보통주',
#         'LS보통주', '대한유화보통주', 'AK홀딩스보통주', '신송홀딩스보통주', '사조산업보통주', '오뚜기보통주',
#         '국도화학보통주', 'F&F보통주', '이건산업보통주', '율촌화학보통주', '한미사이언스보통주', '경인전자보통주',
#         '엔케이물산보통주', '영원무역홀딩스보통주', '아이에스동서보통주', 'S-Oil보통주', 'S-Oil1우선주',
#         '롯데케미칼보통주', '성안보통주', '유양디앤유보통주', '금호석유화학보통주', 'DB Inc.보통주',
#         '에스원보통주', '대창보통주', '동원시스템즈보통주', '유니드 보통주', '인디에프보통주', '한국전력공사보통주',
#         '웅진보통주', '수산중공업보통주', '현대엘리베이터보통주', '하이트론씨스템즈보통주', '대교우선주(신형)',
#         '한섬보통주', '아시아나항공 보통주', '롯데쇼핑 보통주', '중소기업은행보통주', '한국단자공업보통주',
#         '미래산업보통주', '한국주강보통주', '동서보통주', '삼성엔지니어링보통주', '동아지질보통주', '케이씨보통주',
#         '필룩스보통주', '한국유나이티드제약 보통주', 'SK보통주', '백산보통주', '강원랜드보통주',
#         '한국가스공사보통주', '팜스코보통주', '키움증권보통주', '에이치디씨아이콘트롤스보통주', '두산인프라코어보통주',
#         '코스맥스비티아이 주식회사 보통주', '한국항공우주산업보통주', '신한금융지주회사보통주', '포스코강판보통주',
#         '세아홀딩스보통주', '다스코보통주', '한라홀딩스보통주', '세이브존I&C보통주', '삼성출판사보통주',
#         '대웅제약보통주', '한세엠케이보통주', '현대백화점보통주', '지역난방공사보통주', '롯데하이마트보통주',
#         'STX중공업보통주', '나노메딕스보통주', '새론오토모티브', '세진중공업보통주', '텔코웨어 보통주',
#         'GS보통주', '씨제이씨지브이 보통주', '현대리바트보통주', '이월드보통주', 'TBH글로벌보통주',
#         '이리츠코크렙기업구조조정부동산투자회사보통주', '한화생명보험보통주', '에이치디씨현대이피보통주', '제주항공보통주',
#         '메타랩스보통주', '아모레퍼시픽 보통주', '세원셀론텍 보통주', '티웨이항공보통주', 'KPX홀딩스보통주',
#         'LF보통주', '효성아이티엑스 보통주', '한국베트남부동산개발특별자산1호투자회사', 'JW홀딩스 보통주',
#         'SK이노베이션 1우선주', '한국철강보통주', '우진보통주', '코오롱인더스트리보통주', '아이마켓코리아보통주',
#         '한국자산신탁보통주', '메리츠금융지주회사보통주', '엔에스쇼핑보통주', '에이자기관리부동산투자회사보통주',
#         '덴티움보통주', '삼양사보통주', '삼양사1우선주', '코리아오토글라스보통주', '하이골드오션3호선박투자회사',
#         '한국타이어앤테크놀로지보통주', '하이골드오션12호국제선박투자회사', '모두투어리츠보통주', '샘표식품보통주',
#         '현대중공업지주보통주', '현대건설기계보통주', '경동도시가스보통주', '아시아나IDT보통주', '쿠쿠홈시스보통주',
#         '신한알파리츠보통주', 'HDC현대산업개발보통주', '효성화학보통주', '에어부산보통주', '한일시멘트보통주',
#         '현대오토에버보통주', '우리금융지주보통주', '롯데리츠보통주', '두산퓨얼셀2우선주(신형)'], dtype='<U33'),
#  14: array(['유유제약1우선주', 'JW중외제약2우선주(신형)', '백광산업보통주', 'KG케미칼보통주', '금양보통주',
#         '종근당홀딩스보통주', '삼화콘덴서공업보통주', '에이프로젠제약보통주', '삼양식품보통주', '대한항공1우선주',
#         '포스코케미칼보통주', '삼영화학공업보통주', '태양금속공업1우선주', '삼익THK보통주', '깨끗한나라1우선주',
#         '코스모화학보통주', '삼성전자1우선주', '코리아써키트2우선주(신형)', '서연보통주', '서흥보통주',
#         '삼성전기1우선주', '대우전자부품보통주', '태영건설보통주', '태영건설우선주', '한창제지보통주',
#         'CJ씨푸드1우선주', '더존비즈온보통주', '한익스프레스보통주', '성문전자1우선주', '일진머티리얼즈보통주',
#         '일진디스플레이보통주', '한미반도체보통주', 'LG화학1우선주', '한국화장품보통주', 'NHN보통주',
#         '두산솔루스보통주', '엘브이엠씨홀딩스보통주'], dtype='<U33')}

# %%
df_symbol = pd.read_csv('./data/cluster_data/stock_info.csv', encoding='euc-kr')
df_symbol = df_symbol[['단축코드', '한글 종목명']]
df_symbol.head(1)
# Out:
#      단축코드        한글 종목명
# 0  098120  (주)마이크로컨텍솔루션

# %%
df_symbol.loc[df_symbol['한글 종목명'] == krx_cluster_names[0][0], '단축코드'].values
# Out:
# array(['003000'], dtype=object)

# %%
for c in krx_cluster_names:
    _names = krx_cluster_names[c]
    globals()[f'symbols_{c}'] = []

    for n in _names:
        symbol_list = df_symbol.loc[df_symbol['한글 종목명'] == n, '단축코드'].tolist()
        if len(symbol_list) > 0:
            globals()[f'symbols_{c}'].append(symbol_list[0])

symbols_0
# Out:
# ['003000', '004920', '005690', '007570', '011000', '016710', '019170']

# %%
all_symbols = []
all_names = []
for n in names:
    _symbol_list = df_symbol.loc[df_symbol['한글 종목명'] == n, '단축코드'].tolist()
    _name_list = df_symbol.loc[df_symbol['한글 종목명'] == n, '한글 종목명'].tolist()
    if len(_symbol_list) > 0:
        all_symbols.append(_symbol_list[0])
        all_names.append(_name_list[0])

# all_names

# %%
len(all_symbols), len(all_names)
# Out:
# (808, 808)

# %%
krx_cluster_names
# Out:
# {0: array(['부광약품보통주', '씨아이테크보통주', '파미셀보통주', '일양약품보통주', '진원생명과학보통주',
#         '대성홀딩스보통주', '신풍제약보통주'], dtype='<U33'),
#  1: array(['씨제이대한통운보통주', '조선내화보통주', '현대해상화재보험보통주', '동양보통주', 'SK네트웍스보통주',
#         '남영비비안보통주', '조흥보통주', '동양물산기업보통주', '쌍용양회공업보통주', '신흥보통주', '녹십자보통주',
#         '대양금속보통주', '한올바이오파마보통주', '지코보통주', '한화갤러리아타임월드보통주', '웅진씽크빅 보통주',
#         '한진중공업 보통주', '비티원보통주', '이마트보통주', '동아에스티보통주', '코스맥스보통주',
#         '금호에이치티보통주', '동아타이어공업보통주'], dtype='<U33'),
#  2: array(['KR모터스보통주', '흥국화재해상보험1우선주', '한진보통주', '오리엔트바이오보통주', '국제약품보통주',
#         '일성신약보통주', '동방보통주', '농심보통주', '깨끗한나라보통주', '덕성1우선주', '삼성SDI보통주',
#         '삼성SDI1우선주', '남선알미늄보통주', 'CJ씨푸드보통주', '모나리자보통주', '신풍제약1우선주',
#         'MH에탄올보통주', '디피씨보통주', '카카오보통주', '엔씨소프트보통주', 'LG화학보통주',
#         '하나유비에스암바토비니켈해외자원개발2호', '한진칼보통주', '삼성바이오로직스보통주', '넷마블보통주',
#         '센트랄모텍보통주', '현대에너지솔루션보통주', '두산솔루스1우선주'], dtype='<U33'),
#  3: array(['하이트진로보통주', '하이트진로홀딩스보통주', '유진투자증권보통주', 'SH에너지화학보통주', '한국화장품제조보통주',
#         '한국석유공업보통주', '우리들제약보통주', '롯데지주1우선주', '남선알미늄1우선주', '한샘보통주',
#         '웰바이오텍보통주', '극동유화보통주', '한솔케미칼보통주', '애경산업보통주', '서원보통주',
#         '신세계인터내셔날보통주', '체시스보통주', '신세계아이앤씨 보통주', '우리들휴브레인보통주', '코오롱머티리얼보통주',
#         '쿠쿠홀딩스보통주', '오리온보통주'], dtype='<U33'),
#  4: array(['하이트진로2우선주(신형)', '하이트진로홀딩스1우선주', '두산1우선주', '두산2우선주(신형)', '대동공업보통주',
#         '영풍보통주', '한국주철관공업보통주', '부국증권보통주', '부국증권1우선주', '에스지충방 보통주',
#         'BYC1우선주', '대상1우선주', '신영증권1우선주', '삼양통상보통주', '한일철강보통주', '한국제지보통주',
#         '세기상사보통주', '동일제강보통주', 'TCC스틸보통주', '진흥기업보통주', '신풍제지보통주', '대유에이텍',
#         '혜인보통주', '한화투자증권보통주', '한화투자증권1우선주', 'IHQ보통주', '진양산업보통주',
#         '에스지세계물산보통주', '태양금속공업보통주', 'NPC보통주', 'NPC1우선주', '남성보통주',
#         '현대비앤지스틸1우선주', '디알비동일보통주', '삼진제약보통주', '넥센보통주', '넥센1우선주',
#         '크라운해태홀딩스보통주', '크라운해태홀딩스1우선주', '원림보통주', '엔에이치투자증권1우선주',
#         '한국전자홀딩스보통주', 'GS건설보통주', '인스코비보통주', '대림통상보통주', '지에스리테일보통주',
#         '일신석재보통주', '에이프로젠케이아이씨보통주', '선도전기보통주', '이수페타시스보통주', '사조동아원보통주',
#         '대동전자보통주', '아남전자보통주', '동양철관보통주', 'KCTC 보통주', '광동제약보통주',
#         '진양폴리우레탄보통주', '화신보통주', '퍼스텍보통주', '유니켐보통주', '신성이엔지보통주', '화승알앤에이보통주',
#         '성문전자보통주', '대창단조보통주', '에이엔피보통주', '광전자보통주', '조일알미늄보통주', '한국종합기술보통주',
#         '인지컨트롤스보통주', 'WISCOM보통주', '한국콜마홀딩스보통주', '대원화성보통주', '한솔홈데코보통주',
#         '마니커보통주', '케이티비투자증권보통주', '콤텍시스템보통주', '황금에스티보통주', '자화전자보통주',
#         '세종공업보통주', '두산중공업보통주', '광주신세계보통주', '상신브레이크보통주', '대우건설보통주',
#         '유니온머티리얼보통주', '동원F&B보통주', '한국전력기술 보통주', '케이티스카이라이프', '테이팩스보통주',
#         '한국투자금융지주보통주', '하이스틸 보통주', '코아스보통주', '농심홀딩스보통주', '일진다이아몬드 보통주',
#         '그린케미칼보통주', '맥쿼리한국인프라투융자회사 보통주', '케이이씨 보통주', '기신정기 보통주',
#         '형지엘리트보통주', 'AJ네트웍스보통주', '해태제과식품주식회사', '락앤락보통주', '케이씨코트렐보통주',
#         'DSR보통주', '한국투자Parallel유전해외자원개발특별자산투자회사1호', '종근당보통주', '서연이화보통주',
#         '만도보통주', '한솔제지보통주', '엘에스전선아시아보통주', '화승엔터프라이즈보통주', 'BGF리테일보통주',
#         '자이에스앤디보통주', '두산퓨얼셀1우선주'], dtype='<U33'),
#  5: array(['한진중공업홀딩스보통주', '조광피혁보통주', '국동보통주', '신한보통주', '일양약품1우선주',
#         '폴루스바이오팜보통주', '키위미디어그룹보통주', '세원정공보통주', '주식회사동남합성', '웅진에너지보통주',
#         '컨버즈보통주', '세화아이엠씨보통주'], dtype='<U33'),
#  6: array(['메리츠화재해상보험보통주', '삼양홀딩스1우선주', '두산보통주', '한국테크놀로지그룹보통주', '노루홀딩스보통주',
#         '삼화페인트공업보통주', '가온전선보통주', '천일고속보통주', '삼성화재해상보험1우선주', '강남제비스코보통주',
#         '한화보통주', '유니온보통주', 'CJ보통주', 'CJ1우선주', 'CJ4우선주(전환)', '만호제강보통주',
#         '대한제분보통주', '지에스글로벌보통주', '대한전선보통주', 'BYC보통주', '현대차증권보통주',
#         '케이비아이동국실업보통주', '대상보통주', '신영증권보통주', '알루코 보통주', '코오롱1우선주', '아세아보통주',
#         '도화엔지니어링보통주', '동성제약보통주', '제일파마홀딩스보통주', '삼영무역보통주', '선창산업보통주',
#         '유성기업보통주', '코오롱글로벌보통주', '성보화학보통주', '일신방직보통주', '대한항공보통주',
#         '쌍용자동차보통주', '대한화섬보통주', '남양유업보통주', '남양유업1우선주', '사조대림보통주',
#         '현대제철 보통주', '한솔홀딩스보통주', '세방1우선주', '삼화왕관보통주', '세방전지보통주',
#         '현대비앤지스틸보통주', '효성보통주', '조광페인트보통주', '신라교역보통주', '휴스틸보통주', '부산주공보통주',
#         '동성화학보통주', '롯데칠성음료1우선주', '신성통상보통주', '한국공항보통주', '삼영전자공업보통주',
#         '신영와코루보통주', '풍산홀딩스보통주', '이수화학보통주', '동원산업보통주', '에스케이디스커버리보통주',
#         '제주은행보통주', '대원전선보통주', '삼성공조보통주', '미래에셋대우1우선주', '벽산보통주',
#         '한국특수형강보통주', '디티알오토모티브보통주', '태평양물산보통주', 'NI스틸보통주', '문배철강보통주',
#         '일정실업보통주', '신원1우선주', '무림피앤피보통주', '삼정펄프 보통주', '한국내화보통주',
#         '한국프랜지공업보통주', '삼호개발 보통주', 'STX보통주', '세우글로벌보통주', '디와이보통주',
#         '계룡건설산업보통주', '금강공업보통주', '영보화학보통주', '사조씨푸드보통주', '한라보통주',
#         '부산도시가스보통주', '예스코홀딩스보통주', '큐로보통주', '태경산업보통주', '대현보통주', '삼성증권보통주',
#         '동부제철보통주', '동부제철1우선주', '한세예스24홀딩스보통주', 'DB금융투자보통주', '퍼시스보통주',
#         '광명전기보통주', '우신시스템보통주', 'E1보통주', '디씨엠보통주', 'KPX케미칼보통주', 'SJM홀딩스보통주',
#         '이구산업보통주', '부국철강 보통주', 'BGF보통주', '팬오션보통주', '신도리코보통주', '제일기획보통주',
#         '케이티보통주', 'LG디스플레이보통주', '신세계건설', '인천도시가스 보통주', 'SK1우선주',
#         '한국토지신탁보통주', '지투알보통주', 'S&T홀딩스보통주', '하나투어보통주', '대우조선해양보통주',
#         '한미글로벌건축사사무소보통주', '케이티씨에스보통주', '케이티아이에스보통주', 'LG전자보통주', 'LG전자1우선주',
#         '휴켐스보통주', '한국투자금융지주1우선주', '금호타이어보통주', 'STX엔진보통주', 'GS1우선주',
#         'LIG넥스원보통주', '동양생명보험보통주', '대한제강 보통주', '대상홀딩스 보통주', '하나금융지주보통주',
#         '진도 보통주', '노루페인트 보통주', '디아이씨 보통주', '이아이디보통주', 'SK이노베이션 보통주',
#         '진양홀딩스보통주', 'S&TC 보통주', '동성코퍼레이션보통주', '이연제약보통주', '한세실업보통주',
#         '미원홀딩스 보통주', '엘지하우시스', '엘지하우시스 1우선주', '영원무역보통주', '조선선재 보통주',
#         '코오롱인더스트리1우선주', 'SJM보통주', '한전산업개발보통주', '선진보통주', '코오롱플라스틱보통주',
#         'BNK금융지주보통주', '하이골드오션8호국제선박투자회사', 'JB금융지주보통주', '아세아시멘트보통주',
#         '드림텍보통주', '제이에스코퍼레이션보통주', '현대코퍼레이션홀딩스보통주', '두산밥캣보통주', '크라운제과보통주',
#         '제일약품보통주', '한화시스템보통주', 'SK케미칼1우선주', '효성중공업보통주', '세아제강보통주',
#         '두산퓨얼셀보통주', '두산솔루스2우선주(신형)', 'NH프라임리츠보통주'], dtype='<U33'),
#  7: array(['흥국화재해상보험2우선주(신형)', '페이퍼코리아보통주', '셀트리온보통주', 'SK케미칼보통주'],
#        dtype='<U33'),
#  8: array(['성창기업지주보통주', '대림산업1우선주', '기아자동차보통주', '삼일제약보통주', '현대건설보통주',
#         '현대건설1우선주', '화천기공보통주', '보해양조보통주', '상상인증권보통주', '삼성제약', 'SK증권보통주',
#         '조비보통주', '경농보통주', '고려산업보통주', '넥센타이어1우선주(신형)', '범양건영보통주', '삼익악기보통주',
#         '디아이보통주', '유안타증권보통주', 'S&T중공업보통주', '넥스트사이언스보통주', '코리안리재보험보통주',
#         '신세계보통주', '고려개발보통주', '현대약품보통주', '한솔테크닉스보통주', '써니전자보통주',
#         '녹십자홀딩스2우선주(신형)', '포스코보통주', '대림B&Co보통주', '에스엘보통주', '한일현대시멘트보통주',
#         '미래에셋대우', '태경화학보통주', '샘표보통주', '호텔신라보통주', '금비보통주', '신원보통주',
#         '경동나비엔보통주', '한국조선해양보통주', 'OCI보통주', 'LS산전보통주', '삼성중공업보통주',
#         '현대미포조선보통주', '현대위아보통주', '부산산업보통주', '한신기계공업보통주', '현대종합상사보통주',
#         '금호석유화학1우선주', '영흥철강 보통주', '영화금속보통주', '현대모비스보통주', '한화에어로스페이스보통주',
#         'HDC보통주', '일성건설보통주', '백광소재보통주', '일진홀딩스보통주', '환인제약보통주', '신대양제지보통주',
#         '명문제약 보통주', 'SK텔레콤보통주', '대교보통주', '다우기술보통주', '에쓰씨엔지니어링보통주',
#         '제이준코스메틱보통주', '남해화학보통주', '세하보통주', '삼성카드 보통주', '교보증권보통주',
#         '신세계푸드보통주', '롯데관광개발 보통주', '삼성생명보험보통주', '케이티앤지보통주', '무학보통주',
#         '주연테크 보통주', '포스코인터내셔널보통주', '한전KPS 보통주', '현대로템보통주', 'DSR제강보통주',
#         '주식회사 용평리조트', '유엔젤보통주', '에이치에스디엔진보통주', '엔케이 보통주', '아모레퍼시픽 1우선주',
#         'SBS미디어홀딩스보통주', '풍산 보통주', 'KB금융지주 보통주', '호전실업보통주', '그랜드코리아레저보통주',
#         '대성에너지보통주', '대성산업보통주', '한미약품보통주', '인터지스보통주', '시디즈보통주',
#         'DGB금융지주보통주', '케이탑리츠보통주', '바다로19호선박투자회사', '애경유화보통주', '한국콜마보통주',
#         '더블유게임즈보통주', '디와이파워보통주', '잇츠한불보통주', 'JW생명과학보통주', '일동제약보통주',
#         '현대일렉트릭보통주', '미원스페셜티케미칼보통주', '진에어보통주', '케이씨텍보통주', '롯데정보통신보통주',
#         '효성첨단소재보통주'], dtype='<U33'),
#  9: array(['유유제약보통주', '유유제약2우선주(신형)', '대원강업보통주', 'LS네트웍스보통주', '한화1우선주',
#         'DB하이텍보통주', 'JW중외제약1우선주', 'DI동일보통주', '한양증권1우선주', '한국수출포장공업보통주',
#         '아세아제지보통주', '한독보통주', '신일산업보통주', '보락보통주', '미원상사보통주', '유안타증권1우선주',
#         'LG보통주', 'LG1우선주', '한창보통주', '현대자동차보통주', '현대자동차1우선주',
#         '현대자동차2우선주(신형)', '현대자동차3우선주(신형)', '화승인더스트리보통주', '삼아알미늄보통주',
#         '카프로보통주', '우성사료보통주', '코리아써키트1우선주', '윌비스보통주', '무림페이퍼보통주',
#         '케이씨그린홀딩스보통주', '모토닉보통주', '삼성중공업1우선주', '우진아이엔에스보통주', '한솔PNS보통주',
#         '화천기계보통주', '평화홀딩스보통주', '에넥스보통주', '경동인베스트보통주', '경인양행보통주', '이스타코보통주',
#         '두올보통주', '삼성에스디에스보통주', '동원금속보통주', '한온시스템보통주', '티에이치엔보통주',
#         '덕양산업보통주', '동원수산보통주', '아주캐피탈보통주', 'NAVER보통주', '제이콘텐트리보통주',
#         '와이지플러스보통주', '진양화학보통주', '유니퀘스트 보통주', '휴비스보통주', '대상홀딩스 1우선주',
#         '현대글로비스보통주', '동양피스톤보통주', '후성 보통주', '씨제이제일제당 주식회사 1우선주', '쌍방울',
#         '일진전기 보통주', '씨에스윈드보통주', '화인베스틸보통주', '미원화학보통주',
#         '한국투자ANKOR유전해외자원개발특별자산투자회사1호(지분증권)', '동일고무벨트보통주', '이노션보통주',
#         '경보제약보통주', '하나제약보통주'], dtype='<U33'),
#  10: array(['대한방직보통주', '동양2우선주(신형)', '서울식품공업보통주', '서울식품공업1우선주', '사조오양보통주',
#         '미래아이앤지보통주', '한농화성보통주', '키다리스튜디오보통주', '우진플라임 보통주', '종근당바이오보통주',
#         '동북아12호선박투자회사보통주', '동북아13호선박투자회사보통주', '씨제이제일제당 주식회사 보통주',
#         '하나유비에스암바토비니켈해외자원개발1호'], dtype='<U33'),
#  11: array(['경방보통주', '대유플러스보통주', '노루홀딩스1우선주', '흥국화재해상보험보통주', 'CS홀딩스보통주',
#         '유수홀딩스보통주', '한화3우선주(신형)', '삼부토건보통주', 'SK증권1우선주', '동양1우선주',
#         '동양3우선주(신형)', 'SK네트웍스1우선주', '신화실업보통주', '대한제당보통주', '대한제당1우선주',
#         '코오롱글로벌1우선주', '방림보통주', '미창석유공업보통주', '한성기업보통주', '삼천리보통주', '한신공영보통주',
#         '성신양회1우선주', '삼광글라스보통주', '빙그레보통주', '모나미보통주', '동부건설보통주', '동부건설1우선주',
#         '에스케이디스커버리1우선주', '대원전선1우선주', '미래에셋대우2우선주(신형)', '동방아그로보통주',
#         '코리아써키트보통주', '대덕전자보통주', '대덕전자1우선주', '메리츠종합금융증권보통주', 'SIMPAC보통주',
#         '우리종합금융보통주', '고려아연보통주', '현대상선보통주', '태림포장보통주', '동원시스템즈1우선주',
#         '서울도시가스보통주', '풀무원보통주', 'SK가스보통주', '세아특수강보통주', '삼원강재 보통주', '인팩보통주',
#         'LG유플러스보통주', '케이에스에스 해운 보통주', '현대홈쇼핑보통주', 'S&T모티브보통주', '동양고속보통주',
#         '미래에셋생명보험보통주', '노루페인트 1우선주', '미래에셋맵스아시아퍼시픽부동산공모1호', '비상교육 보통주',
#         'SK디앤디보통주', '크라운제과1우선주', '롯데제과보통주'], dtype='<U33'),
#  12: array(['에스케이하이닉스보통주', '한양증권보통주', '진흥기업1우선주(신형)', '진흥기업2우선주(신형)', '덕성보통주',
#         '코스모신소재보통주', '삼성전자보통주', '대구백화점보통주', '영풍제지보통주', '호텔신라1우선주',
#         '삼성전기보통주', '한솔로지스틱스보통주', '참엔지니어링보통주', '삼화전기보통주', 'LG이노텍보통주',
#         '삼화전자공업보통주', '갤럭시아에스엠보통주', 'SKC보통주', '계양전기보통주', '계양전기1우선주',
#         '청호컴넷보통주', '까뮤이앤씨보통주', '지엠비코리아보통주', '지누스보통주', '대영포장보통주',
#         '금강공업1우선주', '한국카본보통주', '삼성물산보통주', '삼성물산1우선주(신형)', '에스비에스보통주',
#         'NICE보통주', 'LG생활건강보통주', 'LG생활건강1우선주', '대호에이엘보통주', '에이블씨엔씨보통주',
#         '평화산업 주식회사 보통주', '현대에이치씨엔보통주', '핸즈코퍼레이션보통주', '한진칼1우선주', '해성디에스보통주',
#         '토니모리보통주', '삼양패키징보통주', '효성티앤씨보통주'], dtype='<U33'),
#  13: array(['동화약품보통주', '삼양홀딩스보통주', '유한양행보통주', '유한양행1우선주', '대림산업보통주',
#         '일동홀딩스보통주', '한화손해보험보통주', '롯데손해보험보통주', '동아쏘시오홀딩스보통주', '이화산업보통주',
#         '삼성화재해상보험보통주', '전방보통주', 'DB하이텍1우선주', 'JW중외제약보통주', 'LG상사보통주',
#         '금호전기보통주', '동국제강보통주', '남광토건보통주', '태원물산보통주', '세아베스틸보통주',
#         '제일연마공업보통주', '대한제당3우선주(신형)', '오리온홀딩스보통주', '삼호보통주', 'KISCO홀딩스보통주',
#         '코오롱보통주', '고려제강보통주', '롯데푸드보통주', '넥센타이어보통주', '주식회사케이씨씨', '화성산업보통주',
#         '아모레G보통주', '아모레G1우선주', '아모레G3우선주(전환)', '한국쉘석유보통주', '금호산업보통주',
#         '금호산업1우선주', '세아제강지주보통주', '대웅보통주', '대원제약보통주', '태광산업보통주', '흥아해운보통주',
#         '한일홀딩스보통주', '쌍용양회공업1우선주', '유화증권보통주', '유화증권1우선주', '영진약품보통주',
#         '대신증권보통주', '대신증권1우선주', '대신증권2우선주(신형)', '보령제약보통주', '롯데정밀화학보통주',
#         '세방보통주', '송원산업보통주', '대림씨엔에스 주식회사', '티웨이홀딩스보통주', '동일산업보통주',
#         '성신양회보통주', '롯데지주보통주', '녹십자홀딩스보통주', '롯데칠성음료보통주', '현대그린푸드보통주',
#         'SPC삼립보통주', 'DB손해보험보통주', '휴니드테크놀러지스보통주', '대한해운보통주', '엔에이치투자증권보통주',
#         'LS보통주', '대한유화보통주', 'AK홀딩스보통주', '신송홀딩스보통주', '사조산업보통주', '오뚜기보통주',
#         '국도화학보통주', 'F&F보통주', '이건산업보통주', '율촌화학보통주', '한미사이언스보통주', '경인전자보통주',
#         '엔케이물산보통주', '영원무역홀딩스보통주', '아이에스동서보통주', 'S-Oil보통주', 'S-Oil1우선주',
#         '롯데케미칼보통주', '성안보통주', '유양디앤유보통주', '금호석유화학보통주', 'DB Inc.보통주',
#         '에스원보통주', '대창보통주', '동원시스템즈보통주', '유니드 보통주', '인디에프보통주', '한국전력공사보통주',
#         '웅진보통주', '수산중공업보통주', '현대엘리베이터보통주', '하이트론씨스템즈보통주', '대교우선주(신형)',
#         '한섬보통주', '아시아나항공 보통주', '롯데쇼핑 보통주', '중소기업은행보통주', '한국단자공업보통주',
#         '미래산업보통주', '한국주강보통주', '동서보통주', '삼성엔지니어링보통주', '동아지질보통주', '케이씨보통주',
#         '필룩스보통주', '한국유나이티드제약 보통주', 'SK보통주', '백산보통주', '강원랜드보통주',
#         '한국가스공사보통주', '팜스코보통주', '키움증권보통주', '에이치디씨아이콘트롤스보통주', '두산인프라코어보통주',
#         '코스맥스비티아이 주식회사 보통주', '한국항공우주산업보통주', '신한금융지주회사보통주', '포스코강판보통주',
#         '세아홀딩스보통주', '다스코보통주', '한라홀딩스보통주', '세이브존I&C보통주', '삼성출판사보통주',
#         '대웅제약보통주', '한세엠케이보통주', '현대백화점보통주', '지역난방공사보통주', '롯데하이마트보통주',
#         'STX중공업보통주', '나노메딕스보통주', '새론오토모티브', '세진중공업보통주', '텔코웨어 보통주',
#         'GS보통주', '씨제이씨지브이 보통주', '현대리바트보통주', '이월드보통주', 'TBH글로벌보통주',
#         '이리츠코크렙기업구조조정부동산투자회사보통주', '한화생명보험보통주', '에이치디씨현대이피보통주', '제주항공보통주',
#         '메타랩스보통주', '아모레퍼시픽 보통주', '세원셀론텍 보통주', '티웨이항공보통주', 'KPX홀딩스보통주',
#         'LF보통주', '효성아이티엑스 보통주', '한국베트남부동산개발특별자산1호투자회사', 'JW홀딩스 보통주',
#         'SK이노베이션 1우선주', '한국철강보통주', '우진보통주', '코오롱인더스트리보통주', '아이마켓코리아보통주',
#         '한국자산신탁보통주', '메리츠금융지주회사보통주', '엔에스쇼핑보통주', '에이자기관리부동산투자회사보통주',
#         '덴티움보통주', '삼양사보통주', '삼양사1우선주', '코리아오토글라스보통주', '하이골드오션3호선박투자회사',
#         '한국타이어앤테크놀로지보통주', '하이골드오션12호국제선박투자회사', '모두투어리츠보통주', '샘표식품보통주',
#         '현대중공업지주보통주', '현대건설기계보통주', '경동도시가스보통주', '아시아나IDT보통주', '쿠쿠홈시스보통주',
#         '신한알파리츠보통주', 'HDC현대산업개발보통주', '효성화학보통주', '에어부산보통주', '한일시멘트보통주',
#         '현대오토에버보통주', '우리금융지주보통주', '롯데리츠보통주', '두산퓨얼셀2우선주(신형)'], dtype='<U33'),
#  14: array(['유유제약1우선주', 'JW중외제약2우선주(신형)', '백광산업보통주', 'KG케미칼보통주', '금양보통주',
#         '종근당홀딩스보통주', '삼화콘덴서공업보통주', '에이프로젠제약보통주', '삼양식품보통주', '대한항공1우선주',
#         '포스코케미칼보통주', '삼영화학공업보통주', '태양금속공업1우선주', '삼익THK보통주', '깨끗한나라1우선주',
#         '코스모화학보통주', '삼성전자1우선주', '코리아써키트2우선주(신형)', '서연보통주', '서흥보통주',
#         '삼성전기1우선주', '대우전자부품보통주', '태영건설보통주', '태영건설우선주', '한창제지보통주',
#         'CJ씨푸드1우선주', '더존비즈온보통주', '한익스프레스보통주', '성문전자1우선주', '일진머티리얼즈보통주',
#         '일진디스플레이보통주', '한미반도체보통주', 'LG화학1우선주', '한국화장품보통주', 'NHN보통주',
#         '두산솔루스보통주', '엘브이엠씨홀딩스보통주'], dtype='<U33')}

# %%
temp_dict = {}
for i in range(len(all_symbols)):
    temp_dict[i] = fdr.DataReader(all_symbols[i], start='2020-04-01', end='2020-05-01')
    temp_dict[i]['Name'] = all_names[i]

b = pd.concat([temp_dict[i] for i in range(len(all_symbols))])
b
# Out:
#             Open  High   Low  Close  Volume    Change         Name
# Date
# 2020-04-01  6610  6780  6500   6580  163650  0.004580      동화약품보통주
# 2020-04-02  6520  6680  6420   6610  146475  0.004559      동화약품보통주
# 2020-04-03  6680  6930  6580   6830  161419  0.033283      동화약품보통주
# 2020-04-06  6930  7220  6930   7190  218593  0.052709      동화약품보통주
# 2020-04-07  7300  7450  6930   7430  179098  0.033380      동화약품보통주
# ...          ...   ...   ...    ...     ...       ...          ...
# 2020-04-23  4053  4315  4040   4223  507662  0.044005  엘브이엠씨홀딩스보통주
# 2020-04-24  4222  4298  4112   4189  269100 -0.008051  엘브이엠씨홀딩스보통주
# 2020-04-27  4193  4222  4146   4164  160986 -0.005968  엘브이엠씨홀딩스보통주
# 2020-04-28  4184  4307  4104   4227  338863  0.015130  엘브이엠씨홀딩스보통주
# 2020-04-29  4265  4298  4193   4206  202169 -0.004968  엘브이엠씨홀딩스보통주
#
# [16100 rows x 7 columns]

# %%
b.iloc[0]['Close']
# Out:
# 6580

# %%
fdr_x = []
fdr_names = []
w = 5
n = 19

for stock_item in tqdm(all_names):
    _df_fdr = b.loc[b['Name'] == stock_item]

    if len(_df_fdr) < n:
        continue

    _df_fdr = _df_fdr.sort_values(by='Date', ascending=True)
    _df_fdr['x'] = _df_fdr['Close'] / _df_fdr.iloc[0]['Close'] - 1

    if len(_df_fdr) < n:
        continue

    _df_fdr['x'] = pd.Series(_df_fdr['x']).rolling(w).mean()
    fdr_x.append(_df_fdr['x'].tolist()[w-1:])
    fdr_names.append(stock_item)

fdr_X = np.array(fdr_x)
fdr_names = np.array(fdr_names)
# Out:
# 100%|██████████| 808/808 [00:02<00:00, 319.62it/s]

# %%
len(fdr_X), len(fdr_names)
# Out:
# (805, 805)

# %%
fdr_model = kmeans_model(x=fdr_X, n_clusters=15, scaler=normalizer)
# Out:
# Counter({5: 152, 2: 130, 0: 103, 4: 100, 3: 65, 12: 60, 14: 57, 13: 41, 1: 21, 10: 19, 11: 14, 9: 13, 7: 13, 6: 9, 8: 8})

# %%
fdr_cluster_names = cluster_itmes(model=fdr_model, names=fdr_names, k=15)
fdr_cluster_names
# Out:
# {0: array(['KR모터스보통주', '유한양행보통주', '하이트진로홀딩스보통주', '두산보통주', '유유제약1우선주',
#         '유유제약2우선주(신형)', '조선내화보통주', '흥국화재해상보험보통주', '천일고속보통주', '페이퍼코리아보통주',
#         'JW중외제약1우선주', '대한방직보통주', '부국증권1우선주', 'DI동일보통주', '오리온홀딩스보통주',
#         '동성제약보통주', '롯데푸드보통주', '한독보통주', '세기상사보통주', '국제약품보통주',
#         '진흥기업1우선주(신형)', '대유에이텍', '한국쉘석유보통주', '유안타증권1우선주', '대신증권보통주',
#         '대신증권2우선주(신형)', '남양유업보통주', '세방전지보통주', '삼천리보통주', '신영와코루보통주',
#         '화승인더스트리보통주', '에스케이디스커버리보통주', '에스케이디스커버리1우선주', '국도화학보통주',
#         '코리아써키트2우선주(신형)', 'SIMPAC보통주', '대양금속보통주', '무림피앤피보통주', '삼성중공업보통주',
#         '현대미포조선보통주', 'S-Oil1우선주', '유니켐보통주', '이스타코보통주', '에이엔피보통주',
#         '대성홀딩스보통주', '두올보통주', '퍼시스보통주', '서울도시가스보통주', '동원금속보통주', '한온시스템보통주',
#         '신풍제약1우선주', '일진디스플레이보통주', '삼원강재 보통주', '다우기술보통주', '디씨엠보통주',
#         '덕양산업보통주', '한국단자공업보통주', 'BGF보통주', '삼성엔지니어링보통주', '케이씨보통주',
#         '한국토지신탁보통주', '광주신세계보통주', '하나투어보통주', '키움증권보통주', '케이에스에스 해운 보통주',
#         '포스코인터내셔널보통주', '우진플라임 보통주', '한전KPS 보통주', '한국전력기술 보통주',
#         '신한금융지주회사보통주', 'LG전자보통주', '롯데하이마트보통주', '새론오토모티브', '세진중공업보통주',
#         '텔코웨어 보통주', 'GS1우선주', 'TBH글로벌보통주', '현대글로비스보통주', '하나금융지주보통주',
#         'KPX홀딩스보통주', 'LF보통주', '미래에셋맵스아시아퍼시픽부동산공모1호',
#         '한국베트남부동산개발특별자산1호투자회사', 'JW홀딩스 보통주', 'SK이노베이션 보통주', '쌍방울', '우진보통주',
#         '대성산업보통주', '한미약품보통주', '이마트보통주', '케이탑리츠보통주',
#         '한국투자ANKOR유전해외자원개발특별자산투자회사1호(지분증권)', '한국타이어앤테크놀로지보통주', '쿠쿠홀딩스보통주',
#         '서연이화보통주', '만도보통주', '경보제약보통주', 'JW생명과학보통주', '크라운제과1우선주', '제일약품보통주',
#         '하나제약보통주', 'HDC현대산업개발보통주', '세아제강보통주'], dtype='<U33'),
#  1: array(['흥국화재해상보험2우선주(신형)', '삼성제약', '범양건영보통주', '서울식품공업1우선주', '빙그레보통주',
#         '엔에이치투자증권1우선주', '남선알미늄1우선주', '한창제지보통주', 'CJ씨푸드1우선주', '하이트론씨스템즈보통주',
#         '대교보통주', '서원보통주', '주연테크 보통주', '비상교육 보통주', '해태제과식품주식회사', '조선선재 보통주',
#         '메리츠금융지주회사보통주', '바다로19호선박투자회사', '한진칼1우선주', '진에어보통주', '신한알파리츠보통주'],
#        dtype='<U33'),
#  2: array(['삼양홀딩스보통주', '하이트진로2우선주(신형)', '하이트진로홀딩스1우선주', '일동홀딩스보통주',
#         '노루홀딩스보통주', '대원강업보통주', '삼일제약보통주', '영풍보통주', '유수홀딩스보통주',
#         '삼성화재해상보험보통주', '삼성화재해상보험1우선주', '화천기공보통주', '한화보통주', '한화3우선주(신형)',
#         'DB하이텍1우선주', 'CJ1우선주', 'JW중외제약보통주', '지에스글로벌보통주', '백광산업보통주',
#         '조비보통주', '한양증권보통주', '대한제당1우선주', '삼화콘덴서공업보통주', '삼양통상보통주',
#         '한국수출포장공업보통주', '한일철강보통주', '화성산업보통주', '제일파마홀딩스보통주', 'TCC스틸보통주',
#         '보락보통주', '아모레G1우선주', '성보화학보통주', '영진약품보통주', 'LG보통주', '방림보통주',
#         '한국석유공업보통주', '한솔홀딩스보통주', '세방보통주', '한신공영보통주', '코스모신소재보통주',
#         '삼진제약보통주', '대림B&Co보통주', '풍산홀딩스보통주', '삼성전자보통주', '삼성전자1우선주',
#         '엔에이치투자증권보통주', '삼아알미늄보통주', 'LS보통주', '영풍제지보통주', '오뚜기보통주',
#         '코리아써키트보통주', 'NI스틸보통주', '문배철강보통주', '아남전자보통주', '한미사이언스보통주',
#         '무림페이퍼보통주', '케이씨그린홀딩스보통주', '삼화전기보통주', 'OCI보통주', '고려아연보통주',
#         '한솔PNS보통주', '화신보통주', 'S-Oil보통주', 'LG이노텍보통주', '태림포장보통주',
#         '한신기계공업보통주', 'HDC보통주', '에스원보통주', '대창보통주', '디와이보통주', '계룡건설산업보통주',
#         '한익스프레스보통주', '영보화학보통주', '성문전자보통주', '대창단조보통주', '일진홀딩스보통주', '광전자보통주',
#         '애경산업보통주', '삼성에스디에스보통주', '조일알미늄보통주', '에쓰씨엔지니어링보통주', 'SJM홀딩스보통주',
#         '남해화학보통주', '한국주강보통주', '동서보통주', '마니커보통주', '세하보통주', '신도리코보통주',
#         '제일기획보통주', '자화전자보통주', '세종공업보통주', '케이티앤지보통주', '무학보통주', '인천도시가스 보통주',
#         '지투알보통주', '대우조선해양보통주', '코스맥스비티아이 주식회사 보통주', 'LG전자1우선주', '한세엠케이보통주',
#         'DSR제강보통주', '한국투자금융지주보통주', '한국투자금융지주1우선주', '휴비스보통주', '에이치에스디엔진보통주',
#         '동양고속보통주', '아모레퍼시픽 보통주', '아모레퍼시픽 1우선주', '디아이씨 보통주', '케이이씨 보통주',
#         '기신정기 보통주', '동양피스톤보통주', '이아이디보통주', '후성 보통주', 'SK이노베이션 1우선주',
#         '일진전기 보통주', '케이씨코트렐보통주', 'SJM보통주', '화인베스틸보통주', 'DSR보통주', '한국콜마보통주',
#         '동아에스티보통주', '종근당보통주', '코스맥스보통주', '제이에스코퍼레이션보통주', '모두투어리츠보통주',
#         '디와이파워보통주', '현대건설기계보통주', 'BGF리테일보통주', '센트랄모텍보통주', '현대에너지솔루션보통주'],
#        dtype='<U33'),
#  3: array(['하이트진로보통주', 'DB하이텍보통주', 'CJ보통주', 'CJ4우선주(전환)', '태원물산보통주', '대상보통주',
#         '대상1우선주', '고려산업보통주', '주식회사케이씨씨', '조흥보통주', '삼양식품보통주', '대신증권1우선주',
#         '한성기업보통주', '사조대림보통주', '롯데정밀화학보통주', '태양금속공업1우선주', 'NPC보통주',
#         '현대약품보통주', '세방1우선주', '삼익THK보통주', '한솔테크닉스보통주', '효성보통주', '덕성보통주',
#         '신라교역보통주', '롯데지주보통주', '롯데칠성음료보통주', '롯데칠성음료1우선주', '현대그린푸드보통주',
#         'AK홀딩스보통주', '지에스리테일보통주', '태평양물산보통주', '율촌화학보통주', '영원무역홀딩스보통주',
#         '한화에어로스페이스보통주', '금강공업1우선주', '한세예스24홀딩스보통주', '신대양제지보통주', '웅진보통주',
#         '한국카본보통주', '키다리스튜디오보통주', '롯데쇼핑 보통주', '팬오션보통주', '콤텍시스템보통주',
#         'LG유플러스보통주', '체시스보통주', 'LG생활건강보통주', '케이티스카이라이프', '현대백화점보통주',
#         '유엔젤보통주', 'LIG넥스원보통주', '씨제이제일제당 주식회사 보통주', '씨제이제일제당 주식회사 1우선주',
#         '이연제약보통주', '한세실업보통주', '영원무역보통주', '씨에스윈드보통주', '대성에너지보통주', '선진보통주',
#         '에이자기관리부동산투자회사보통주', '삼양사보통주', '한국투자Parallel유전해외자원개발특별자산투자회사1호',
#         '금호에이치티보통주', '오리온보통주', '효성티앤씨보통주', '자이에스앤디보통주'], dtype='<U33'),
#  4: array(['유한양행1우선주', '노루홀딩스1우선주', '한화손해보험보통주', '롯데손해보험보통주', 'CS홀딩스보통주',
#         '동아쏘시오홀딩스보통주', '한국주철관공업보통주', '금호전기보통주', '동국제강보통주', '대한전선보통주',
#         'SK증권1우선주', '케이비아이동국실업보통주', '코오롱보통주', '코오롱1우선주', '아세아보통주',
#         '아세아제지보통주', '넥센타이어보통주', '삼익악기보통주', '오리엔트바이오보통주', '아모레G보통주',
#         '아모레G3우선주(전환)', '유성기업보통주', '세아제강지주보통주', '코오롱글로벌보통주', '코오롱글로벌1우선주',
#         '일성신약보통주', '일신방직보통주', '대원제약보통주', '태광산업보통주', '한국화장품제조보통주',
#         '유안타증권보통주', '대한항공보통주', '한화투자증권보통주', '한화투자증권1우선주', '남양유업1우선주',
#         '현대제철 보통주', '에스지세계물산보통주', '신흥보통주', '동일산업보통주', '휴스틸보통주',
#         '현대자동차1우선주', '현대자동차3우선주(신형)', '코스모화학보통주', 'SPC삼립보통주', '삼영전자공업보통주',
#         '넥센보통주', '넥센1우선주', '대한해운보통주', '한국전자홀딩스보통주', '삼성공조보통주', '신송홀딩스보통주',
#         '코리아써키트1우선주', '사조동아원보통주', '참엔지니어링보통주', '한올바이오파마보통주', '모토닉보통주',
#         '화천기계보통주', '현대위아보통주', '갤럭시아에스엠보통주', '영화금속보통주', '세우글로벌보통주',
#         '대영포장보통주', 'DB금융투자보통주', 'E1보통주', '대교우선주(신형)', 'KPX케미칼보통주',
#         '제이준코스메틱보통주', '한솔홈데코보통주', '롯데관광개발 보통주', '삼성생명보험보통주', '에스비에스보통주',
#         '강원랜드보통주', '신세계아이앤씨 보통주', '한국가스공사보통주', '상신브레이크보통주', '종근당바이오보통주',
#         '세이브존I&C보통주', '셀트리온보통주', '동양생명보험보통주', '대상홀딩스 보통주', '미래에셋생명보험보통주',
#         'AJ네트웍스보통주', '그랜드코리아레저보통주', '락앤락보통주', '한국화장품보통주', '한국자산신탁보통주',
#         '인터지스보통주', '코오롱플라스틱보통주', 'BNK금융지주보통주', 'DGB금융지주보통주', '잇츠한불보통주',
#         '일동제약보통주', '미원스페셜티케미칼보통주', '동아타이어공업보통주', '현대오토에버보통주', '우리금융지주보통주',
#         '두산퓨얼셀보통주', '두산퓨얼셀1우선주', '두산퓨얼셀2우선주(신형)', '엘브이엠씨홀딩스보통주'],
#        dtype='<U33'),
#  5: array(['경방보통주', '메리츠화재해상보험보통주', '삼양홀딩스1우선주', '성창기업지주보통주', '삼화페인트공업보통주',
#         '가온전선보통주', 'LS네트웍스보통주', '현대건설보통주', '이화산업보통주', '보해양조보통주', '전방보통주',
#         'JW중외제약2우선주(신형)', '만호제강보통주', '부국증권보통주', 'KG케미칼보통주', '현대해상화재보험보통주',
#         'SK증권보통주', '한양증권1우선주', '알루코 보통주', 'KISCO홀딩스보통주', '경농보통주', '한진보통주',
#         '넥센타이어1우선주(신형)', '동일제강보통주', '진흥기업보통주', '신풍제지보통주', '디아이보통주',
#         '한일홀딩스보통주', '유화증권보통주', '유화증권1우선주', '한진중공업홀딩스보통주', 'LG1우선주',
#         'IHQ보통주', '태양금속공업보통주', '동방보통주', '신세계보통주', 'NPC1우선주', '삼화왕관보통주',
#         '현대비앤지스틸보통주', '티웨이홀딩스보통주', '조광페인트보통주', '부산주공보통주', '모나미보통주',
#         '신성통상보통주', '원림보통주', '동부건설보통주', '제주은행보통주', '대원전선보통주', 'GS건설보통주',
#         '카프로보통주', '인스코비보통주', '벽산보통주', '동방아그로보통주', '이건산업보통주', '호텔신라보통주',
#         '호텔신라1우선주', '금비보통주', 'KCTC 보통주', '삼성전기보통주', '삼성전기1우선주',
#         '한솔로지스틱스보통주', '한샘보통주', '태영건설보통주', '태영건설우선주', '한국내화보통주',
#         '우리종합금융보통주', '한국프랜지공업보통주', '삼성중공업1우선주', '우진아이엔에스보통주', '평화홀딩스보통주',
#         '삼화전자공업보통주', '성안보통주', 'STX보통주', 'DB Inc.보통주', '계양전기보통주', '경인양행보통주',
#         '지엠비코리아보통주', '금강공업보통주', '한솔케미칼보통주', '유니드 보통주', '예스코홀딩스보통주',
#         '태경산업보통주', '대현보통주', '광명전기보통주', 'SK텔레콤보통주', 'SK가스보통주', '세아특수강보통주',
#         '한섬보통주', '일진머티리얼즈보통주', '한국종합기술보통주', '인지컨트롤스보통주', '한국콜마홀딩스보통주',
#         '대원화성보통주', '이구산업보통주', '삼성물산보통주', '삼성물산1우선주(신형)', '케이티보통주',
#         '교보증권보통주', '동원수산보통주', '신세계인터내셔날보통주', '황금에스티보통주', '신세계건설',
#         'NICE보통주', 'SK보통주', '팜스코보통주', '한미반도체보통주', '대우건설보통주', '유니온머티리얼보통주',
#         'LG화학1우선주', '한미글로벌건축사사무소보통주', '세아홀딩스보통주', '케이티씨에스보통주',
#         '케이티아이에스보통주', '대웅제약보통주', '하이스틸 보통주', '코아스보통주', 'STX중공업보통주',
#         '유니퀘스트 보통주', '에이블씨엔씨보통주', '씨제이씨지브이 보통주', '일진다이아몬드 보통주', '대한제강 보통주',
#         '엔케이 보통주', '한화생명보험보통주', '진도 보통주', '맥쿼리한국인프라투융자회사 보통주', '제주항공보통주',
#         '티웨이항공보통주', '형지엘리트보통주', '효성아이티엑스 보통주', '웅진씽크빅 보통주', '진양홀딩스보통주',
#         '한국철강보통주', '미원홀딩스 보통주', '아이마켓코리아보통주', '한전산업개발보통주', '시디즈보통주',
#         '덴티움보통주', '삼양사1우선주', '삼성바이오로직스보통주', '한솔제지보통주', '이노션보통주', '토니모리보통주',
#         '엘에스전선아시아보통주', '샘표식품보통주', '경동도시가스보통주', '아시아나IDT보통주', '삼양패키징보통주',
#         '롯데정보통신보통주', '효성중공업보통주', '효성첨단소재보통주', '한일시멘트보통주'], dtype='<U33'),
#  6: array(['대한제분보통주', '흥아해운보통주', '웰바이오텍보통주', 'CJ씨푸드보통주', '사조씨푸드보통주',
#         '세원정공보통주', '백산보통주', '컨버즈보통주', 'JB금융지주보통주'], dtype='<U33'),
#  7: array(['흥국화재해상보험1우선주', '진흥기업2우선주(신형)', '진양산업보통주', '녹십자홀딩스보통주', '에스엘보통주',
#         '일양약품보통주', '서연보통주', '한국조선해양보통주', '인팩보통주', '삼성카드 보통주',
#         '한국유나이티드제약 보통주', '넷마블보통주', 'SK케미칼1우선주'], dtype='<U33'),
#  8: array(['에이프로젠제약보통주', '남성보통주', '농심보통주', '국동보통주', '대동전자보통주', '남선알미늄보통주',
#         '환인제약보통주', '부국철강 보통주'], dtype='<U33'),
#  9: array(['대유플러스보통주', '현대자동차보통주', '현대자동차2우선주(신형)', '경인전자보통주', '진원생명과학보통주',
#         '신성이엔지보통주', '현대모비스보통주', '중소기업은행보통주', 'LG디스플레이보통주', '금호타이어보통주',
#         '메타랩스보통주', '코오롱인더스트리보통주', '코오롱인더스트리1우선주'], dtype='<U33'),
#  10: array(['남광토건보통주', 'BYC보통주', '제일연마공업보통주', '쌍용자동차보통주', '씨아이테크보통주', '파미셀보통주',
#         '크라운해태홀딩스보통주', '대원전선1우선주', '대림통상보통주', '대한유화보통주', '롯데케미칼보통주',
#         '지누스보통주', '현대로템보통주', '이리츠코크렙기업구조조정부동산투자회사보통주', '에이치디씨현대이피보통주',
#         '크라운제과보통주', '한화시스템보통주', '롯데리츠보통주', 'NH프라임리츠보통주'], dtype='<U33'),
#  11: array(['두산1우선주', '두산2우선주(신형)', '신영증권보통주', '신영증권1우선주', '서울식품공업보통주',
#         '써니전자보통주', '일양약품1우선주', '일정실업보통주', '성문전자1우선주', '우신시스템보통주',
#         '미래산업보통주', '진양화학보통주', 'SK디앤디보통주', 'SK케미칼보통주'], dtype='<U33'),
#  12: array(['씨제이대한통운보통주', '현대건설1우선주', '강남제비스코보통주', '유니온보통주', '상상인증권보통주',
#         'BYC1우선주', '삼부토건보통주', '종근당홀딩스보통주', '도화엔지니어링보통주', '미원상사보통주',
#         '부광약품보통주', '혜인보통주', '대한항공1우선주', '포스코케미칼보통주', '대한화섬보통주',
#         '현대비앤지스틸1우선주', '성신양회보통주', '성신양회1우선주', '한창보통주', '한국공항보통주',
#         '크라운해태홀딩스1우선주', '이수화학보통주', '동부건설1우선주', '대구백화점보통주', '한일현대시멘트보통주',
#         '삼성SDI보통주', '삼성SDI1우선주', '일신석재보통주', '선도전기보통주', '윌비스보통주', '동양철관보통주',
#         '신원보통주', '광동제약보통주', '대우전자부품보통주', '경동나비엔보통주', '에넥스보통주', '부산산업보통주',
#         'SKC보통주', '계양전기1우선주', '경동인베스트보통주', '더존비즈온보통주', '일성건설보통주',
#         '인디에프보통주', '큐로보통주', '수산중공업보통주', '현대엘리베이터보통주', '아시아나항공 보통주',
#         'WISCOM보통주', '동아지질보통주', '와이지플러스보통주', 'LG화학보통주', '테이팩스보통주',
#         '다스코보통주', '주식회사 용평리조트', '지역난방공사보통주', '한진칼보통주', '아세아시멘트보통주',
#         '현대코퍼레이션홀딩스보통주', '두산밥캣보통주', '에어부산보통주'], dtype='<U33'),
#  13: array(['유유제약보통주', '에스케이하이닉스보통주', '동양보통주', '동양1우선주', '동양2우선주(신형)',
#         '대한제당보통주', '고려제강보통주', 'SH에너지화학보통주', '깨끗한나라보통주', '깨끗한나라1우선주',
#         '조광피혁보통주', '덕성1우선주', '녹십자홀딩스2우선주(신형)', '녹십자보통주', '미래아이앤지보통주',
#         '삼정펄프 보통주', '진양폴리우레탄보통주', '아이에스동서보통주', '모나리자보통주', '극동유화보통주',
#         '동원시스템즈보통주', '동원시스템즈1우선주', '삼성증권보통주', '명문제약 보통주', '신풍제약보통주',
#         '티에이치엔보통주', 'MH에탄올보통주', '엔씨소프트보통주', '한라홀딩스보통주', '삼성출판사보통주',
#         '농심홀딩스보통주', 'GS보통주', '이월드보통주', 'KB금융지주 보통주', '호전실업보통주',
#         '핸즈코퍼레이션보통주', '해성디에스보통주', '화승엔터프라이즈보통주', '롯데제과보통주', '케이씨텍보통주',
#         '쿠쿠홈시스보통주'], dtype='<U33'),
#  14: array(['동화약품보통주', '한화1우선주', '유진투자증권보통주', '현대차증권보통주', '금양보통주', 'SK네트웍스보통주',
#         'SK네트웍스1우선주', '삼영무역보통주', '대웅보통주', '미창석유공업보통주', '코리안리재보험보통주',
#         '삼영화학공업보통주', '송원산업보통주', '디알비동일보통주', '롯데지주1우선주', 'DB손해보험보통주',
#         '휴니드테크놀러지스보통주', '동원산업보통주', '사조오양보통주', '사조산업보통주', '샘표보통주',
#         '이수페타시스보통주', '서흥보통주', '퍼스텍보통주', '삼호개발 보통주', '한농화성보통주', '금호석유화학보통주',
#         '금호석유화학1우선주', '까뮤이앤씨보통주', '한라보통주', '한국전력공사보통주', '풀무원보통주',
#         '주식회사동남합성', '신세계푸드보통주', 'SK1우선주', 'NAVER보통주', '카카오보통주',
#         '한국항공우주산업보통주', '동원F&B보통주', 'LG생활건강1우선주', '현대홈쇼핑보통주', '대호에이엘보통주',
#         'STX엔진보통주', '현대리바트보통주', '그린케미칼보통주', '대상홀딩스 1우선주', '평화산업 주식회사 보통주',
#         '노루페인트 보통주', '노루페인트 1우선주', '풍산 보통주', '미원화학보통주', '동일고무벨트보통주',
#         'NHN보통주', '더블유게임즈보통주', '드림텍보통주', '현대일렉트릭보통주', '효성화학보통주'],
#        dtype='<U33')}

# %%
import matplotlib.font_manager as fm
import matplotlib
from scipy.spatial.distance import euclidean

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = 'Malgun Gothic'
fm.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font_name)
matplotlib.rc('axes', unicode_minus=False)

def plot_clusters(model, X, names, k):
    # %matplotlib inline
    c = 4
    fig, axes = plt.subplots(nrows=k, ncols=c+1, figsize=(c*3, k*2))

    for label in range(k):
        x = model.cluster_centers_[label]
        axes[label][0].plot(np.arange(len(x)), x)
        axes[label][0].set_title(f'Cluster_{label}: Trend')
        axes[label][0].set_ylim([min(x.min()-0.01, 0.1), max(x.max()+0.01, 0.1)])
        n = 0
        _X = X[model.labels_ == label]
        _names = names[model.labels_ == label]
        dist = [euclidean(x, _x) for _x in _X]
        idxs = np.argsort(dist)[:c]

        for x, name in zip(_X[idxs], _names[idxs]):
            n += 1
            axes[label][n].plot(np.arange(len(x)), x)
            axes[label][n].set_title(f'{label}: {name}')
            axes[label][n].set_ylim([min(x.min()-0.01, 0.1), max(x.max()+0.01, 0.1)])
            if n >= c:
                break

    plt.tight_layout()
    plt.show()

plot_clusters(krx_model, krx_X, krx_names, 15)

# %%
plot_clusters(fdr_model, fdr_X, fdr_names, 15)

# %%
plt.plot(krx_model.cluster_centers_)
# Out:
# [<matplotlib.lines.Line2D at 0x2c84cec5310>,
#  <matplotlib.lines.Line2D at 0x2c84cec5370>,
#  <matplotlib.lines.Line2D at 0x2c84cec5490>,
#  <matplotlib.lines.Line2D at 0x2c83fe8d250>,
#  <matplotlib.lines.Line2D at 0x2c83fe8d280>,
#  <matplotlib.lines.Line2D at 0x2c84cec56d0>,
#  <matplotlib.lines.Line2D at 0x2c84cec57f0>,
#  <matplotlib.lines.Line2D at 0x2c84cec5910>,
#  <matplotlib.lines.Line2D at 0x2c84cec5a30>,
#  <matplotlib.lines.Line2D at 0x2c84cec5b50>,
#  <matplotlib.lines.Line2D at 0x2c84cec5c70>,
#  <matplotlib.lines.Line2D at 0x2c84cec5340>,
#  <matplotlib.lines.Line2D at 0x2c84cec5e80>,
#  <matplotlib.lines.Line2D at 0x2c84cec5fa0>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5100>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5220>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5340>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5460>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5580>,
#  <matplotlib.lines.Line2D at 0x2c84ceb56a0>,
#  <matplotlib.lines.Line2D at 0x2c84ceb57c0>,
#  <matplotlib.lines.Line2D at 0x2c84ceb58e0>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5a00>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5b20>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5c40>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5d60>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5e80>,
#  <matplotlib.lines.Line2D at 0x2c84ceb5fa0>,
#  <matplotlib.lines.Line2D at 0x2c84cecb100>,
#  <matplotlib.lines.Line2D at 0x2c84cecb220>,
#  <matplotlib.lines.Line2D at 0x2c84cecb340>,
#  <matplotlib.lines.Line2D at 0x2c84cecb460>,
#  <matplotlib.lines.Line2D at 0x2c84cecb580>,
#  <matplotlib.lines.Line2D at 0x2c84cecb6a0>,
#  <matplotlib.lines.Line2D at 0x2c84cecb7c0>,
#  <matplotlib.lines.Line2D at 0x2c84cecb8e0>,
#  <matplotlib.lines.Line2D at 0x2c84cecba00>,
#  <matplotlib.lines.Line2D at 0x2c84cecbb20>,
#  <matplotlib.lines.Line2D at 0x2c84cecbc40>,
#  <matplotlib.lines.Line2D at 0x2c84cecbd60>,
#  <matplotlib.lines.Line2D at 0x2c84cecbe80>,
#  <matplotlib.lines.Line2D at 0x2c84cecbfa0>,
#  <matplotlib.lines.Line2D at 0x2c84cea0c40>,
#  <matplotlib.lines.Line2D at 0x2c84cea0640>,
#  <matplotlib.lines.Line2D at 0x2c84cea0070>,
#  <matplotlib.lines.Line2D at 0x2c84cea0df0>,
#  <matplotlib.lines.Line2D at 0x2c84cea0dc0>,
#  <matplotlib.lines.Line2D at 0x2c84cea0af0>,
#  <matplotlib.lines.Line2D at 0x2c84cea0ac0>,
#  <matplotlib.lines.Line2D at 0x2c84cea07f0>,
#  <matplotlib.lines.Line2D at 0x2c84cea07c0>,
#  <matplotlib.lines.Line2D at 0x2c84cea04f0>,
#  <matplotlib.lines.Line2D at 0x2c84cea0490>,
#  <matplotlib.lines.Line2D at 0x2c84cea0250>,
#  <matplotlib.lines.Line2D at 0x2c84cea0130>,
#  <matplotlib.lines.Line2D at 0x2c84cea0550>,
#  <matplotlib.lines.Line2D at 0x2c84ceaf100>,
#  <matplotlib.lines.Line2D at 0x2c84ceaf220>]

# %%
plt.plot(fdr_model.cluster_centers_)
# Out:
# [<matplotlib.lines.Line2D at 0x2c84c5e3730>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3790>,
#  <matplotlib.lines.Line2D at 0x2c84c5e38b0>,
#  <matplotlib.lines.Line2D at 0x2c84c5e39d0>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3af0>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3c10>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3d30>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3e50>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3f70>,
#  <matplotlib.lines.Line2D at 0x2c84c5eb0d0>,
#  <matplotlib.lines.Line2D at 0x2c84c5e3700>,
#  <matplotlib.lines.Line2D at 0x2c84c5eb1f0>,
#  <matplotlib.lines.Line2D at 0x2c84c5eb400>,
#  <matplotlib.lines.Line2D at 0x2c84c5eb520>,
#  <matplotlib.lines.Line2D at 0x2c84c5eb640>,
#  <matplotlib.lines.Line2D at 0x2c84c5eb760>]

# %%
def dict_to_df(cluster_names):
    temp_dict = {}
    for i  in cluster_names:
        temp_dict[i] = pd.DataFrame(cluster_names[i])
        temp_dict[i]['cluster'] = i
    
    temp_df = pd.concat([temp_dict[i] for i in range(len(temp_dict))])
    temp_df = temp_df.reset_index(drop=True)
    return temp_df

# %%
fdr_name_cluster_df = dict_to_df(fdr_cluster_names)
fdr_name_cluster_df
# Out:
#                0  cluster
# 0       KR모터스보통주        0
# 1        유한양행보통주        0
# 2    하이트진로홀딩스보통주        0
# 3          두산보통주        0
# 4       유유제약1우선주        0
# ..           ...      ...
# 800       NHN보통주       14
# 801    더블유게임즈보통주       14
# 802       드림텍보통주       14
# 803    현대일렉트릭보통주       14
# 804      효성화학보통주       14
#
# [805 rows x 2 columns]

# %%
krx_name_cluster_df = dict_to_df(krx_cluster_names)
krx_name_cluster_df
# Out:
#                0  cluster
# 0        부광약품보통주        0
# 1       씨아이테크보통주        0
# 2         파미셀보통주        0
# 3        일양약품보통주        0
# 4      진원생명과학보통주        0
# ..           ...      ...
# 900     LG화학1우선주       14
# 901     한국화장품보통주       14
# 902       NHN보통주       14
# 903     두산솔루스보통주       14
# 904  엘브이엠씨홀딩스보통주       14
#
# [905 rows x 2 columns]

# %%
normalizer = Normalizer()

# %%
plt.plot(fdr_model.cluster_centers_[1])

# %% [markdown]
# ## AutoML(pycaret)

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

# %%
j = get_data('jewellery')
j
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130
#      Age  Income  SpendingScore       Savings
# 0     58   77769       0.791329   6559.829923
# 1     59   81799       0.791082   5417.661426
# 2     62   74751       0.702657   9258.992965
# 3     59   74373       0.765680   7346.334504
# 4     87   17760       0.348778  16869.507130
# ..   ...     ...            ...           ...
# 500   28  101206       0.387441  14936.775389
# 501   93   19934       0.203140  17969.693769
# 502   90   35297       0.355149  16091.401954
# 503   91   20681       0.354679  18401.088445
# 504   89   30267       0.289310  14386.351880
#
# [505 rows x 4 columns]

# %%
data_selected = data_2020[['거래일자', '시가', '고가', '저가', '종가', '거래량']]

# %%
clu1 = setup(data=j, normalize=True)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     01:48:21
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\bigcare\Desktop\hoon\prac\practices\projects\dacon\idea_competition\krx-big-data.ipynb 셀 83 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bigcare/Desktop/hoon/prac/practices/projects/dacon/idea_competition/krx-big-data.ipynb#ch0000075?line=0'>1</a> clu1 = setup(data=j, normalize=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\clustering.py:384, in setup(data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, group_features, group_names, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     381 if log_plots == True:
#     382     log_plots = ["cluster", "distribution", "elbow"]
# --> 384 return pycaret.internal.tabular.setup(
#     385     ml_usecase="clustering",
#     386     available_plots=available_plots,
#     387     data=data,
#     388     target=None,
#     389     preprocess=preprocess,
#     390     imputation_type=imputation_type,
#     391     iterative_imputation_iters=iterative_imputation_iters,
#     392     categorical_features=categorical_features,
#     393     categorical_imputation=categorical_imputation,
#     394     categorical_iterative_imputer=categorical_iterative_imputer,
#     395     ordinal_features=ordinal_features,
#     396     high_cardinality_features=high_cardinality_features,
#     397     high_cardinality_method=high_cardinality_method,
#     398     numeric_features=numeric_features,
#     399     numeric_imputation=numeric_imputation,
#     400     numeric_iterative_imputer=numeric_iterative_imputer,
#     401     date_features=date_features,
#     402     ignore_features=ignore_features,
#     403     normalize=normalize,
#     404     normalize_method=normalize_method,
#     405     transformation=transformation,
#     406     transformation_method=transformation_method,
#     407     handle_unknown_categorical=handle_unknown_categorical,
#     408     unknown_categorical_method=unknown_categorical_method,
#     409     pca=pca,
#     410     pca_method=pca_method,
#     411     pca_components=pca_components,
#     412     ignore_low_variance=ignore_low_variance,
#     413     combine_rare_levels=combine_rare_levels,
#     414     rare_level_threshold=rare_level_threshold,
#     415     bin_numeric_features=bin_numeric_features,
#     416     remove_outliers=False,
#     417     remove_multicollinearity=remove_multicollinearity,
#     418     multicollinearity_threshold=multicollinearity_threshold,
#     419     remove_perfect_collinearity=remove_perfect_collinearity,
#     420     create_clusters=False,
#     421     polynomial_features=False,
#     422     trigonometry_features=False,
#     423     group_features=group_features,
#     424     group_names=group_names,
#     425     feature_selection=False,
#     426     feature_interaction=False,
#     427     feature_ratio=False,
#     428     fix_imbalance=False,
#     429     data_split_shuffle=False,
#     430     data_split_stratify=False,
#     431     n_jobs=n_jobs,
#     432     use_gpu=use_gpu,
#     433     custom_pipeline=custom_pipeline,
#     434     html=html,
#     435     session_id=session_id,
#     436     log_experiment=log_experiment,
#     437     experiment_name=experiment_name,
#     438     log_plots=log_plots,
#     439     log_profile=log_profile,
#     440     log_data=log_data,
#     441     silent=silent,
#     442     verbose=verbose,
#     443     profile=profile,
#     444     profile_kwargs=profile_kwargs,
#     445 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\tabular.py:1210, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1202 from sklearn.model_selection import (
#    1203     StratifiedKFold,
#    1204     KFold,
#    1205     GroupKFold,
#    1206     TimeSeriesSplit,
#    1207 )
#    1209 if fold_strategy == "kfold":
# -> 1210     fold_generator = KFold(
#    1211         fold_param, random_state=seed, shuffle=fold_shuffle_param
#    1212     )
#    1213 elif fold_strategy == "stratifiedkfold":
#    1214     fold_generator = StratifiedKFold(
#    1215         fold_param, random_state=seed, shuffle=fold_shuffle_param
#    1216     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_split.py:435, in KFold.__init__(self, n_splits, shuffle, random_state)
#     434 def __init__(self, n_splits=5, *, shuffle=False, random_state=None):
# --> 435     super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_split.py:296, in _BaseKFold.__init__(self, n_splits, shuffle, random_state)
#     293     raise TypeError("shuffle must be True or False; got {0}".format(shuffle))
#     295 if not shuffle and random_state is not None:  # None is the default
# --> 296     raise ValueError(
#     297         "Setting a random_state has no effect since shuffle is "
#     298         "False. You should leave "
#     299         "random_state to its default (None), or set shuffle=True.",
#     300     )
#     302 self.n_splits = n_splits
#     303 self.shuffle = shuffle
#
# ValueError: Setting a random_state has no effect since shuffle is False. You should leave random_state to its default (None), or set shuffle=True.
